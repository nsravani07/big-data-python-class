# %% [markdown]
# # Homework 3  - Tryout pandas and numpy
#
# Copy this notebook. Rename it as: YOURNAME-Homework-panda-numpy-Sept-2017
#
# with your name replacing yourname and  replaced with the date you submit or to the last part.
#
# Do the homeworks problems below.
#
# Upload your completed jupyter notebook to your github site and send me the url via the elearning site as your homework submission. Please note that you need to do your own 3.4, and 3.5 if you share data and analysis from others then you cannot get more than a 3.

# %% [markdown]
# ## Homework 3.1
#
# ### 3.1.a
# Load the data from: http://opendata.dc.gov/datasets that I have include in this github
# into a dataframe.  ( The file has been is available in directory ./data/ccp_current_csv.csv )

# %%
import os
os.chdir("C:\Users\Vishnu\Desktop\Big Data Analytics")

# %%
import pandas as pd

# %%
data = pd.read_table("ccp_current_csv.csv", sep=',', header=None)
data
# Out:
#                      0         1                           2   \
# 0                STREET  QUADRANT            FROMINTERSECTION
# 1               13th St        NW                  Kennedy St
# 2                  S St        NW            North Capitol St
# 3      Rhode Island Ave        NE            Brentwood Rd (W)
# 4               Mill Rd        NW                     27th St
# 5      Rhode Island Ave        NE            Brentwood Rd (M)
# 6             Mellon St        SE                      5th St
# 7          Nebraska Ave        NW              Northampton St
# 8           Military Rd        NW                     30th St
# 9          Nebraska Ave        NW                   Oliver St
# 10              16th St        NW                  Alaska Ave
# 11         Shoemaker St        NW                 Linnean Ave
# 12         Underwood St        NW             Piney Branch Rd
# 13             Elder St        NW                      7th St
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### 3.1.a  what is its shape and what does that mean?

# %%
data.shape
# Out:
# (466, 27)

# %% [markdown]
# Shape returns a tuple representing the dimensionality of the DataFrame. The tuple contains the number of rows and columns of a dataframe i.e. 466 - represents the number of rows and 27 - represents the number of columns.

# %% [markdown]
# ## Homework 3.2
#  What are the number of rows in each 'QUADRANT' ?

# %%
ccp_current = pd.read_csv("ccp_current_csv.csv", dtype = None)

# %%
ccp_current.columns
# Out:
# Index([u'STREET', u'QUADRANT', u'FROMINTERSECTION', u'TOINTERSECTION',
#        u'NOOFBLOCKS', u'WORKDESCRIPTION', u'YEARBUDGETED', u'PERCENTCOMPLETED',
#        u'STATUS', u'MILES', u'WARD', u'FUNCTIONALCLASS', u'ESTIMATEDSTARTDATE',
#        u'ESTIMATEDCOMPLETIONDATE', u'ACTUALCOMPLETIONDATE', u'REMARKS',
#        u'XCOORD', u'YCOORD', u'LATITUDE', u'LONGITUDE', u'PROJECTNOTE',
#        u'PROJECTNAME', u'PROJECTMGR', u'PROJECTID', u'TEAMREP', u'EMAIL',
#        u'CONTACTPHONE'],
#       dtype='object')

# %%
ccp_current['QUADRANT']
# Out:
# 0      NW
# 1      NW
# 2      NE
# 3      NW
# 4      NE
# 5      SE
# 6      NW
# 7      NW
# 8      NW
# 9      NW
# 10     NW
# 11     NW
# 12     NW
# 13     NW
# 14     NW
# 15     NW
# 16     NW
# 17     NE
# 18     NE
# 19     NE
# 20     SE
# 21     NW
# 22     NE
# 23     SW
# 24     NW
# 25     NW
# 26     NW
# 27     NW
# 28     NW
# 29     NW
#        ..
# 435    NW
# 436    NE
# 437    BN
# 438    NE
# 439    NE
# 440    SE
# 441    NW
# 442    NE
# 443    NW
# 444    NE
# 445    NE
# 446    SE
# 447    NW
# 448    NE
# 449    NE
# 450    NW
# 451    SE
# 452    SW
# 453    NW
# 454    NW
# 455    NW
# 456    NW
# 457    NW
# 458    SW
# 459    NW
# 460    NW
# 461    NW
# 462    NW
# 463    NE
# 464    BN
# Name: QUADRANT, Length: 465, dtype: object

# %%
qd_info = ccp_current['QUADRANT'].value_counts()
pd.DataFrame(qd_info)
# Out:
#     QUADRANT
# NW       195
# NE       163
# SE        84
# BN        12
# SW        11

# %%
ccp_current.groupby(ccp_current['QUADRANT']).size()
# Out:
# QUADRANT
# BN     12
# NE    163
# NW    195
# SE     84
# SW     11
# dtype: int64

# %% [markdown]
# ## Homework 3.3 - Array math demonstration
# For two arrarys
#
# a= [1,2,3,4]  type=float
#
# b= [5,6,7,8]  type=float
#
# Peform the following array operations using numpy
# ( show both operational use of numpy and functional (example addition operation => + vs addition function => numbpy.add() )
#
# ### 3.3.1 addition a+b

# %%
import numpy 
from numpy import *
a = array([1, 2, 3, 4], dtype=float)
b = array([5, 6, 7, 8], dtype=float)

# %%
a + b
# Out:
# array([  6.,   8.,  10.,  12.])

# %%
numpy.add(a, b)
# Out:
# array([  6.,   8.,  10.,  12.])

# %% [markdown]
# ### 3.3.2 subtraction a-b

# %%
a - b
# Out:
# array([-4., -4., -4., -4.])

# %%
numpy.subtract(a, b)
# Out:
# array([-4., -4., -4., -4.])

# %% [markdown]
# ### 3.3.3 multiplication a*b

# %%
a * b
# Out:
# array([  5.,  12.,  21.,  32.])

# %%
numpy.multiply(a, b)
# Out:
# array([  5.,  12.,  21.,  32.])

# %% [markdown]
# ### 3.3.4 divsion a/b

# %%
a / b
# Out:
# array([ 0.2       ,  0.33333333,  0.42857143,  0.5       ])

# %%
numpy.divide(a, b)
# Out:
# array([ 0.2       ,  0.33333333,  0.42857143,  0.5       ])

# %% [markdown]
# ### 3.3.5 modulo  a%b

# %%
a % b
# Out:
# array([ 1.,  2.,  3.,  4.])

# %%
numpy.mod(a, b)
# Out:
# array([ 1.,  2.,  3.,  4.])

# %%
numpy.remainder(a, b)
# Out:
# array([ 1.,  2.,  3.,  4.])

# %% [markdown]
# ### 3.3.6 power  a^b

# %%
a ** b
# Out:
# array([  1.00000000e+00,   6.40000000e+01,   2.18700000e+03,
#          6.55360000e+04])

# %%
numpy.power(a, b)
# Out:
# array([  1.00000000e+00,   6.40000000e+01,   2.18700000e+03,
#          6.55360000e+04])

# %% [markdown]
# ## Homework 3.4
# Find your own data and load it into a dataframe

# %%
d = pd.read_table("ahca_polls.csv", sep=',', header=None)
d
# Out:
#           0        1                         2      3       4  \
# 0     Start      End                  Pollster  Favor  Oppose
# 1    6/9/17  6/11/17     Public Policy Polling     24      55
# 2    6/4/17   6/6/17                    YouGov     33      45
# 3   5/31/17   6/6/17                 Qunnipiac     17      62
# 4   5/26/17  5/30/17                    IPSOS      30      46
# 5   5/25/17  5/30/17           Morning Consult     38      47
# 6   5/17/17  5/23/17                Quinnipiac     20      57
# 7   5/16/17  5/22/17  Kaiser Family Foundation     31      55
# 8   5/13/17  5/20/17                  Monmouth     32      55
# 9   5/13/17  5/16/17                    YouGov     31      47
# 10  5/12/17  5/16/17     Public Policy Polling     25      52
# 11  5/11/17  5/15/17                   NBC/WSJ     23      48
# 12   5/6/17  5/13/17                    YouGov     31      44
# 13   5/6/17   5/6/17                    YouGov     31      47
# ...

# %% [markdown]
# ## Homework 3.5
# Provide an interesting analysis of the data columns ( frequency or averages )

# %%
import pandas as pd

# %%
a = pd.read_csv("ahca_polls.csv", dtype = None)
a
# Out:
#       Start      End                  Pollster  Favor  Oppose  \
# 0    6/9/17  6/11/17     Public Policy Polling     24      55
# 1    6/4/17   6/6/17                    YouGov     33      45
# 2   5/31/17   6/6/17                 Qunnipiac     17      62
# 3   5/26/17  5/30/17                    IPSOS      30      46
# 4   5/25/17  5/30/17           Morning Consult     38      47
# 5   5/17/17  5/23/17                Quinnipiac     20      57
# 6   5/16/17  5/22/17  Kaiser Family Foundation     31      55
# 7   5/13/17  5/20/17                  Monmouth     32      55
# 8   5/13/17  5/16/17                    YouGov     31      47
# 9   5/12/17  5/16/17     Public Policy Polling     25      52
# 10  5/11/17  5/15/17                   NBC/WSJ     23      48
# 11   5/6/17  5/13/17                    YouGov     31      44
# 12   5/6/17   5/6/17                    YouGov     31      47
# 13   5/4/17  5/10/17                Quinnipiac     21      56
# ...

# %%
## unique values in a column "Pollster"

# %%
uniq = a['Pollster'].unique()
uniq
# Out:
# array(['Public Policy Polling', 'YouGov', 'Qunnipiac', 'IPSOS ',
#        'Morning Consult', 'Quinnipiac', 'Kaiser Family Foundation',
#        'Monmouth', 'NBC/WSJ'], dtype=object)

# %%
## mean of a column "Favor"

# %%
a['Favor'].mean()
# Out:
# 28.333333333333332

# %%
## Sum of the values in a column "Favor"

# %%
a['Favor'].sum()
# Out:
# 425L

# %%
## finding average of all the values in a column "Favor"

# %%
avg1 = a['Favor'].sum() / a['Favor'].shape[0]
avg1
# Out:
# 28L

# %%
## mean of a column "Oppose"

# %%
a['Oppose'].mean()
# Out:
# 50.666666666666664

# %%
## Sum of the values in a column "Oppose"

# %%
avg2 = a['Oppose'].sum() / a['Oppose'].shape[0]
avg2
# Out:
# 50L

# %%
## create a copy

# %%
a_cpy = a.copy()

# %%
## Modify a value in the column "Pollster"

# %%
a_cpy.loc[2, 'Pollster'] = 'Quinnipiac'
a_cpy
# Out:
#       Start      End                  Pollster  Favor  Oppose  \
# 0    6/9/17  6/11/17     Public Policy Polling     24      55
# 1    6/4/17   6/6/17                    YouGov     33      45
# 2   5/31/17   6/6/17                Quinnipiac     17      62
# 3   5/26/17  5/30/17                    IPSOS      30      46
# 4   5/25/17  5/30/17           Morning Consult     38      47
# 5   5/17/17  5/23/17                Quinnipiac     20      57
# 6   5/16/17  5/22/17  Kaiser Family Foundation     31      55
# 7   5/13/17  5/20/17                  Monmouth     32      55
# 8   5/13/17  5/16/17                    YouGov     31      47
# 9   5/12/17  5/16/17     Public Policy Polling     25      52
# 10  5/11/17  5/15/17                   NBC/WSJ     23      48
# 11   5/6/17  5/13/17                    YouGov     31      44
# 12   5/6/17   5/6/17                    YouGov     31      47
# 13   5/4/17  5/10/17                Quinnipiac     21      56
# ...

# %%
## occurance of each value in the column "Pollster"

# %%
l = list(a_cpy['Pollster'])

# %%
count = {i: l[:].count(i) for i in list(l[:])}

# %%
print "value", "counts"
for x in sorted(count.keys()):
    print x , count[x]
# Out:
# value counts
# IPSOS  1
# Kaiser Family Foundation 1
# Monmouth 1
# Morning Consult 2
# NBC/WSJ 1
# Public Policy Polling 2
# Quinnipiac 3
# YouGov 4

# %%
pd.DataFrame(count.items())
# Out:
#                           0  1
# 0                  Monmouth  1
# 1           Morning Consult  2
# 2                Quinnipiac  3
# 3                    IPSOS   1
# 4                    YouGov  4
# 5  Kaiser Family Foundation  1
# 6                   NBC/WSJ  1
# 7     Public Policy Polling  2

# %%
## returns the start dates that are not unique

# %%
a_cpy['Start'].value_counts() > 1
# Out:
# 5/6/17      True
# 5/13/17     True
# 5/4/17      True
# 5/12/17    False
# 5/11/17    False
# 5/17/17    False
# 5/31/17    False
# 6/9/17     False
# 5/25/17    False
# 6/4/17     False
# 5/26/17    False
# 5/16/17    False
# Name: Start, dtype: bool

# %%
## Add a new column

# %%
a_cpy['Total'] = a_cpy['Favor'] + a_cpy['Oppose']
a_cpy[['Total']]
# Out:
#     Total
# 0      79
# 1      78
# 2      79
# 3      76
# 4      85
# 5      77
# 6      86
# 7      87
# 8      78
# 9      77
# 10     71
# 11     75
# 12     78
# 13     77
# 14     82

# %%
## return 'Favor', 'Oppose' and 'Total' votes for "Yougov" (in a column "Pollster")

# %%
yougov = a_cpy.loc[a_cpy['Pollster'] == 'YouGov']
yougov[['Favor','Oppose','Total']]
# Out:
#     Favor  Oppose  Total
# 1      33      45     78
# 8      31      47     78
# 11     31      44     75
# 12     31      47     78

# %%
## return the rows where the total votes are greater than 80

# %%
a_cpy[a_cpy['Total'] > 80]
# Out:
#       Start      End                  Pollster  Favor  Oppose  \
# 4   5/25/17  5/30/17           Morning Consult     38      47
# 6   5/16/17  5/22/17  Kaiser Family Foundation     31      55
# 7   5/13/17  5/20/17                  Monmouth     32      55
# 14   5/4/17   5/9/17           Morning Consult     38      44
#
#                                                   Url  \
# 4   https://morningconsult.com/wp-content/uploads/...
# 6   http://files.kff.org/attachment/Topline-Kaiser...
# 7   https://www.monmouth.edu/polling-institute/rep...
# 14  http://www.politico.com/f/?id=0000015b-ef3e-d4...
#
#                                                  Text  Total
# 4   As you may know, the House of Representatives ...     85
# 6   As you may know, Congress is currently discuss...     86
# 7   Earlier this month, the House of Representativ...     87
# 14  As you may know, the House of Representatives ...     82

# %%
## return the maximum values for the columns 'Favor', 'Oppose', 'Total'

# %%
a_cpy[['Favor','Oppose','Total']].max()
# Out:
# Favor     38
# Oppose    62
# Total     87
# dtype: int64

# %%
## return the rows that has a maximum values for the columns 'Favor', 'Oppose', 'Total'

# %%
a_cpy.loc[a_cpy[['Favor','Oppose','Total']].idxmax()]
# Out:
#      Start      End         Pollster  Favor  Oppose  \
# 4  5/25/17  5/30/17  Morning Consult     38      47
# 2  5/31/17   6/6/17       Quinnipiac     17      62
# 7  5/13/17  5/20/17         Monmouth     32      55
#
#                                                  Url  \
# 4  https://morningconsult.com/wp-content/uploads/...
# 2  https://poll.qu.edu/national/release-detail?Re...
# 7  https://www.monmouth.edu/polling-institute/rep...
#
#                                                 Text  Total
# 4  As you may know, the House of Representatives ...     85
# 2  There is a revised Republican health care plan...     79
# 7  Earlier this month, the House of Representativ...     87

# %%
## return the rows where the value of the column 'Oppose' is greater than 60

# %%
mask = (a_cpy.Oppose > 60)
a_cpy[mask]
# Out:
#      Start     End    Pollster  Favor  Oppose  \
# 2  5/31/17  6/6/17  Quinnipiac     17      62
#
#                                                  Url  \
# 2  https://poll.qu.edu/national/release-detail?Re...
#
#                                                 Text  Total
# 2  There is a revised Republican health care plan...     79

# %%
## sum the values in the columns 'Favor', 'Oppose' and 'Total' for the similar values in 'Pollster'

# %%
poll = a_cpy.groupby('Pollster').sum()
poll
# Out:
#                           Favor  Oppose  Total
# Pollster
# IPSOS                        30      46     76
# Kaiser Family Foundation     31      55     86
# Monmouth                     32      55     87
# Morning Consult              76      91    167
# NBC/WSJ                      23      48     71
# Public Policy Polling        49     107    156
# Quinnipiac                   58     175    233
# YouGov                      126     183    309

# %%
## bar graph showing the Favor and Oppose votes for each value in 'Pollster'

# %%
import matplotlib.pyplot as plt
ax = poll[['Favor', 'Oppose']].plot(kind='bar', figsize=(15, 10), fontsize=12)
ax.set_title('Votes Comparison', fontsize=20)
ax.set_ylabel("Votes", fontsize=12)
plt.show()

# %%
## return the rows that has the same values in 'Start' and 'End'

# %%
a_cpy.loc[a_cpy['Start'].isin(a_cpy['End'])]
# Out:
#       Start      End                  Pollster  Favor  Oppose  \
# 6   5/16/17  5/22/17  Kaiser Family Foundation     31      55
# 7   5/13/17  5/20/17                  Monmouth     32      55
# 8   5/13/17  5/16/17                    YouGov     31      47
# 11   5/6/17  5/13/17                    YouGov     31      44
# 12   5/6/17   5/6/17                    YouGov     31      47
#
#                                                   Url  \
# 6   http://files.kff.org/attachment/Topline-Kaiser...
# 7   https://www.monmouth.edu/polling-institute/rep...
# 8   https://d25d2506sfb94s.cloudfront.net/cumulus_...
# 11  http://big.assets.huffingtonpost.com/tabsHPHea...
# 12  https://d25d2506sfb94s.cloudfront.net/cumulus_...
#
#                                                  Text  Total
# 6   As you may know, Congress is currently discuss...     86
# 7   Earlier this month, the House of Representativ...     87
# 8   Overall, given what you know about them, do yo...     78
# ...

# %%
## divide the data into 2 parts

# %%
import numpy as np
qd = np.array_split(a_cpy, 2)

# %%
qd[0] ## data in the first part
# Out:
#      Start      End                  Pollster  Favor  Oppose  \
# 0   6/9/17  6/11/17     Public Policy Polling     24      55
# 1   6/4/17   6/6/17                    YouGov     33      45
# 2  5/31/17   6/6/17                Quinnipiac     17      62
# 3  5/26/17  5/30/17                    IPSOS      30      46
# 4  5/25/17  5/30/17           Morning Consult     38      47
# 5  5/17/17  5/23/17                Quinnipiac     20      57
# 6  5/16/17  5/22/17  Kaiser Family Foundation     31      55
# 7  5/13/17  5/20/17                  Monmouth     32      55
#
#                                                  Url  \
# 0  http://www.publicpolicypolling.com/pdf/2017/PP...
# 1  https://d25d2506sfb94s.cloudfront.net/cumulus_...
# 2  https://poll.qu.edu/national/release-detail?Re...
# 3  https://www.realclearpolitics.com/docs/Core_Po...
# 4  https://morningconsult.com/wp-content/uploads/...
# 5  https://poll.qu.edu/national/release-detail?Re...
# ...

# %%
rows_part1 = (qd[0].shape)[0]
print rows_part1
# Out:
# 8
