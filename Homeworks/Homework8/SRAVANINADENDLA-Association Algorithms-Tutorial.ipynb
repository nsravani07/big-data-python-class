# %% [markdown]
# Association Rules
# -------------------
#
# Association rules analysis is a technique to uncover how items are associated to each other.
#
# There are three common ways to measure association:
#
# * Measure 1: Support - This says how popular an itemset is, as measured by the proportion of transactions in which an
#     itemset appears.
#
# * Measure 2: Confidence - This says how likely item Y is purchased when item X is purchased, expressed as {X -> Y}. This is
#     measured by the proportion of transactions with item X, in which item Y also appears.
#
# * Measure 3: Lift - This says how likely item Y is purchased when item X is purchased, while controlling for how popular item     Y is.

# %% [markdown]
# ## Apriori algorithm

# %% [markdown]
# The Apriori algorithm principle says that if an itemset is frequent, then all of its subsets are frequent.this means that if {0,1} is frequent, then {0} and {1} have to be frequent.
#
# The rule turned around says that if an itemset is infrequent, then its supersets are also infrequent.
#
# We first need to find the frequent itemsets, and then we can find association rules.

# %%
## Copied from http://adataanalyst.com/machine-learning/apriori-algorithm-python-3-0/

# %%
dataset = [line.split() for line in open('Trafficdata.csv').readlines()]
dataset
# Out:
# [['Year,Case',
#   'Vehicle',
#   'ID,Vehicle',
#   'Body',
#   'Type,Registration',
#   'Class,Action',
#   'Prior',
#   'to',
#   'Accident,Type',
#   '/',
#   'Axles',
#   'of',
#   'Truck',
#   'or',
#   'Bus,Direction',
#   'of',
#   'Travel,Fuel',
#   'Type,Vehicle',
#   'Year,State',
#   'of',
#   'Registration,Number',
#   'of',
#   'Occupants,Engine',
#   'Cylinders,Vehicle',
#   'Make,Contributing',
#   'Factor',
#   '1,Contributing',
#   'Factor',
#   '1',
#   'Description,Contributing',
#   'Factor',
#   '2,Contributing',
#   'Factor',
#   '2',
#   'Description,Event',
#   'Type,Partial',
#   'VIN'],
#  ['2013,11256149,2',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Backing,Not',
#   'Entered,South,Not',
#   'Entered,2013,NY,1,,HOND,HUMAN,Backing',
#   'Unsafely,HUMAN,Driver',
#   'Inattention/Distraction*,Not',
#   'Applicable,'],
#  ['2013,11330798,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Overtaking/Passing,Not',
#   'Entered,North,Not',
#   'Entered,2013,VA,1,,DODG,HUMAN,Unsafe',
#   'Lane',
#   'Changing,HUMAN,Passing',
#   'or',
#   'Lane',
#   'Usage',
#   'Improper,"Overturned,',
#   'Non-Collision",'],
#  ['2013,11053659,2',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,East,Not',
#   "Entered,2010,PA,1,,NISS,ENVMT,Animal's",
#   'Action,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2013,10831549,POLICE',
#   'VEHICLE,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,East,Not',
#   "Entered,2012,NY,1,,FORD,ENVMT,Animal's",
#   'Action,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2013,10890741,SUBURBAN,Not',
#   'Entered,Changing',
#   'Lanes,Not',
#   'Entered,North,Not',
#   'Entered,2006,NJ,3,,DODG,ENVMT,Pavement',
#   'Slippery,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2013,11095421,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Making',
#   'Left',
#   'Turn,Not',
#   'Entered,Northwest,Not',
#   'Entered,2013,TN,1,,TOYT,HUMAN,Failure',
#   'to',
#   'Yield',
#   'Right-of-Way,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2012,10001283,4',
#   'DOOR',
#   'SEDAN,DEALER,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,East,None,2001,NY,1,0,DODGE,HUMAN,Not',
#   'Applicable,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2012,10454932,4',
#   'DOOR',
#   'SEDAN,DEALER,Going',
#   'Straight',
#   'Ahead,Not',
#   "Entered,East,None,2012,NY,1,0,CHRY,ENVMT,Animal's",
#   'Action,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2012,10742629,DUMP,Not',
#   'Entered,Making',
#   'Right',
#   'Turn,Not',
#   'Entered,Southwest,None,2001,NY,1,0,MAC,HUMAN,Unsafe',
#   'Lane',
#   'Changing,HUMAN,Driver',
#   'Inattention/Distraction*,Not',
#   'Applicable,'],
#  ['2012,10915394,4',
#   'DOOR',
#   'SEDAN,DEALER,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,South,None,2006,NY,1,0,ME/BE,HUMAN,Following',
#   'Too',
#   'Closely,HUMAN,Not',
#   'Entered,Not',
#   'Entered,'],
#  ['2013,11376104,SUBURBAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,South,Not',
#   'Entered,2007,NY,2,,FORD,HUMAN,Failure',
#   'to',
#   'Yield',
#   'Right-of-Way,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2013,10950427,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Parked,Not',
#   'Entered,South,Not',
#   'Entered,1998,NY,0,,MAZD,HUMAN,Not',
#   'Applicable,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,1YVGF22D3W5'],
#  ['2013,11245573,TRACTOR,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,East,Not',
#   'Entered,2000,NJ,1,,FRHT,HUMAN,Unsafe',
#   'Speed,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,IU201417285'],
#  ['2013,11094257,PICKUP',
#   'TRUCK,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,East,Not',
#   "Entered,2007,MS,1,,CHEV,ENVMT,Animal's",
#   'Action,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2013,11202923,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Slowing',
#   'or',
#   'Stopping,Not',
#   'Entered,North,Not',
#   'Entered,2013,IL,2,,FORD,HUMAN,Not',
#   'Applicable,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,1FADP3F28DL'],
#  ['2013,10944884,DELIVERY',
#   'TRUCK,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,North,Not',
#   'Entered,1988,UN,1,,GRUM,HUMAN,Not',
#   'Applicable,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,1GBBS10EXK2'],
#  ['2013,11078782,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Slowing',
#   'or',
#   'Stopping,Not',
#   'Entered,East,Not',
#   'Entered,2012,NJ,1,,CHEV,HUMAN,Not',
#   'Applicable,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2012,11143993,TRACTOR,SEMI-TRAILER,Making',
#   'Right',
#   'Turn,Not',
#   'Entered,South,None,2012,NY,1,0,AM/HA,HUMAN,Not',
#   'Entered,HUMAN,Not',
#   'Entered,Not',
#   'Entered,5N6200F20C1'],
#  ['2013,11169688,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Making',
#   'Left',
#   'Turn,Not',
#   'Entered,South,Not',
#   'Entered,2005,NY,4,,TOYT,HUMAN,Not',
#   'Applicable,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2013,11161588,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,North,Not',
#   'Entered,2012,NJ,4,,AUDI,VEHICLE,Other*,HUMAN,Not',
#   'Applicable,"Other',
#   'Motor',
#   'Vehicle,',
#   'Collision',
#   'With",WA1CGAFE8CD'],
#  ['2013,11386643,MOTORCYCLE,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,North,Not',
#   'Entered,2007,NJ,1,,HA/DA,HUMAN,Unknown,HUMAN,Not',
#   'Entered,Not',
#   'Applicable,1HD1JL5147Y'],
#  ['2013,11388795,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Making',
#   'Right',
#   'Turn,Not',
#   'Entered,Northeast,Not',
#   'Entered,2010,NY,1,,CHEV,HUMAN,Failure',
#   'to',
#   'Yield',
#   'Right-of-Way,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2013,10949728,SUBURBAN,Not',
#   'Entered,Making',
#   'Left',
#   'Turn,Not',
#   'Entered,South,Not',
#   'Entered,2013,NJ,1,,FORD,HUMAN,Driver',
#   'Inattention/Distraction*,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2013,11592276,FLAT',
#   'BED',
#   'TRUCK,COMMERCIAL,Stopped',
#   'in',
#   'Traffic,Not',
#   'Entered,East,Gas,2008,NY,1,10,FORD,HUMAN,Not',
#   'Applicable,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,1FDAF56Y38E'],
#  ['2013,11324702,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,North,Not',
#   'Entered,2011,MA,1,,CHEV,HUMAN,Not',
#   'Applicable,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,2G1WB5EK7B1'],
#  ['2013,11386243,TRACTOR,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,East,Not',
#   'Entered,2009,OK,1,,FRHT,HUMAN,Driver',
#   'Inattention/Distraction*,HUMAN,Following',
#   'Too',
#   'Closely,Not',
#   'Applicable,1FUJBBCK39L'],
#  ['2013,10809401,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,East,Not',
#   'Entered,2012,NJ,1,,HYUN,HUMAN,Not',
#   'Applicable,HUMAN,Not',
#   'Applicable,Not',
#   'Entered,5NPDH4AE1CH'],
#  ['2013,11034074,Not',
#   'Entered,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,South,Not',
#   'Entered,,,1,,,HUMAN,Unknown,HUMAN,Unknown,Not',
#   'Applicable,'],
#  ['2013,11560358,PICKUP',
#   'TRUCK,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,South,Not',
#   'Entered,2006,AK,4,,TOYT,HUMAN,Unsafe',
#   'Speed,ENVMT,Pavement',
#   'Slippery,Not',
#   'Applicable,5TBET34116S'],
#  ['2013,11610502,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,North,Not',
#   'Entered,2008,CT,1,,NISS,HUMAN,Not',
#   'Applicable,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,3N1AB61E38L'],
#  ['2013,10931825,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,West,Not',
#   'Entered,2007,CT,1,,VOLV,ENVMT,View',
#   'Obstructed/Limited,HUMAN,Failure',
#   'to',
#   'Yield',
#   'Right-of-Way,"Earth',
#   'Embankment/Rock',
#   'Cut/Ditch,',
#   'Collision',
#   'With',
#   'Fixed',
#   'Object",YV1RH592672'],
#  ['2013,11115701,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Parked,Not',
#   'Entered,Unknown,Not',
#   'Entered,2008,CT,0,,HYUN,HUMAN,Not',
#   'Applicable,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,5NPET46C98H'],
#  ['2013,10999745,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,East,Not',
#   'Entered,2009,MN,1,,VOLV,HUMAN,Following',
#   'Too',
#   'Closely,HUMAN,Not',
#   'Applicable,Not',
#   'Entered,'],
#  ['2013,11526173,FIRE',
#   'VEHICLE,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,Southeast,Not',
#   'Entered,2009,NY,1,,SPTN,HUMAN,Passing',
#   'or',
#   'Lane',
#   'Usage',
#   'Improper,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,4S7AU2F969C'],
#  ['2013,11423026,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,Southeast,Not',
#   'Entered,2005,PA,3,,CHRY,HUMAN,Aggressive',
#   'Driving/Road',
#   'Rage,HUMAN,Failure',
#   'to',
#   'Keep',
#   'Right,Not',
#   'Applicable,3C4FY48B05T'],
#  ['2013,11308219,SUBURBAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,Northwest,Not',
#   'Entered,2006,CT,1,,TOYT,HUMAN,Failure',
#   'to',
#   'Yield',
#   'Right-of-Way,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2013,11633945,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,Southeast,Not',
#   'Entered,2013,NY,2,,HYUN,HUMAN,Following',
#   'Too',
#   'Closely,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2013,11395783,TRACTOR,Not',
#   'Entered,Making',
#   'Right',
#   'Turn,Not',
#   'Entered,North,Not',
#   'Entered,2003,PA,1,,KW,HUMAN,Unknown,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,1XKWD89X23J'],
#  ['2013,11457986,SUBURBAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,North,Not',
#   'Entered,2004,CT,1,,FORD,HUMAN,Alcohol',
#   'Involvement,HUMAN,Fell',
#   'Asleep,Not',
#   'Applicable,'],
#  ['2013,10950672,SUBURBAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,South,Not',
#   'Entered,2012,NJ,1,,LEXS,HUMAN,Failure',
#   'to',
#   'Yield',
#   'Right-of-Way,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,JTJBM7FX8C5'],
#  ['2013,11179199,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Making',
#   'Left',
#   'Turn,Not',
#   'Entered,Northwest,Not',
#   'Entered,2010,FL,1,,FORD,HUMAN,Turning',
#   'Improperly,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2013,11299375,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Making',
#   'Left',
#   'Turn,Not',
#   'Entered,West,Not',
#   'Entered,2004,PA,1,,PONT,HUMAN,Failure',
#   'to',
#   'Yield',
#   'Right-of-Way,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2013,11572398,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,South,Not',
#   'Entered,2013,MD,1,,FORD,HUMAN,Following',
#   'Too',
#   'Closely,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2013,11495022,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,South,Not',
#   'Entered,2000,CT,1,,TOYT,HUMAN,Following',
#   'Too',
#   'Closely,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,4T1BF22K3YU'],
#  ['2013,11783575,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,South,Not',
#   'Entered,2010,NY,1,,HONDA,HUMAN,Following',
#   'Too',
#   'Closely,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2013,11132317,SUBURBAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,East,Not',
#   'Entered,2006,MA,5,,FORD,HUMAN,Not',
#   'Applicable,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,1FMFU18526L'],
#  ['2013,10920491,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,North,Not',
#   'Entered,2007,NY,1,,TOYT,ENVMT,Pavement',
#   'Slippery,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2013,11549669,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,North,Not',
#   'Entered,2005,PA,1,,TOYT,HUMAN,Traffic',
#   'Control',
#   'Device',
#   'Disregarded,HUMAN,Not',
#   'Applicable,"Overturned,',
#   'Non-Collision",2T1BR32E35C'],
#  ['2013,10861000,VAN',
#   'TRUCK,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,West,Not',
#   'Entered,2003,PA,1,,INTE,ENVMT,Pavement',
#   'Slippery,ENVMT,View',
#   'Obstructed/Limited,"Other',
#   'Motor',
#   'Vehicle,',
#   'Collision',
#   'With",4KAMGABMX3A'],
#  ['2012,10459509,MOTORCYCLE,CLASS',
#   'B',
#   'LIMITED',
#   'USE',
#   'MOTORCYCLE,Making',
#   'Right',
#   'Turn,Not',
#   'Entered,Northeast,Gas,2005,NY,1,1,HONDA,HUMAN,Not',
#   'Applicable,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,JH2AF60415K'],
#  ['2013,10800352,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,South,Not',
#   'Entered,2011,ME,1,,CADI,HUMAN,Prescription',
#   'Medication,HUMAN,Unsafe',
#   'Lane',
#   'Changing,Not',
#   'Applicable,'],
#  ['2012,10194609,PICKUP',
#   'TRUCK,POLITICAL',
#   'SUBDIVISION,Stopped',
#   'in',
#   'Traffic,Not',
#   'Entered,East,Gas,2008,NY,2,10,FORD,HUMAN,Not',
#   'Applicable,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,1FTWX31Y28E'],
#  ['2013,11481774,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,West,Not',
#   'Entered,2008,GA,1,,LEXS,HUMAN,Driver',
#   'Inattention/Distraction*,HUMAN,Not',
#   'Applicable,Not',
#   'Entered,JTHBE96S380'],
#  ['2013,11023684,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,North,Not',
#   'Entered,2005,NY,1,,TOYT,ENVMT,Pavement',
#   'Slippery,HUMAN,Unsafe',
#   'Speed,"Tree,',
#   'Collision',
#   'With',
#   'Fixed',
#   'Object",'],
#  ['2013,11595087,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Slowing',
#   'or',
#   'Stopping,Not',
#   'Entered,West,Not',
#   'Entered,2010,NJ,2,,TOYT,HUMAN,Not',
#   'Applicable,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,4T1BB3EK4AU'],
#  ['2013,11572845,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Stopped',
#   'in',
#   'Traffic,Not',
#   'Entered,South,Not',
#   'Entered,2012,VA,1,,NISS,HUMAN,Not',
#   'Applicable,HUMAN,Not',
#   'Applicable,Not',
#   'Entered,'],
#  ['2013,11336198,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,North,Not',
#   'Entered,1994,NJ,1,,HOND,HUMAN,Not',
#   'Applicable,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2013,11343055,PICKUP',
#   'TRUCK,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,North,Not',
#   'Entered,2006,NY,1,,FORD,HUMAN,Not',
#   "Applicable,ENVMT,Animal's",
#   'Action,Not',
#   'Applicable,'],
#  ['2013,11582492,SUBURBAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,West,Not',
#   'Entered,2001,NJ,1,,SUBA,HUMAN,Not',
#   'Applicable,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2013,11502543,TRACTOR,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,West,Not',
#   'Entered,2007,IA,1,,FRHT,HUMAN,Traffic',
#   'Control',
#   'Device',
#   'Disregarded,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,1FUJBBAV27L'],
#  ['2013,11544573,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Slowing',
#   'or',
#   'Stopping,Not',
#   'Entered,West,Not',
#   'Entered,2009,NY,1,,HOND,HUMAN,Not',
#   'Applicable,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2013,11153609,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,East,Not',
#   'Entered,2004,SC,1,,FORD,HUMAN,Following',
#   'Too',
#   'Closely,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,1FMZU63K44U'],
#  ['2013,11395761,TRACTOR,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,North,Not',
#   'Entered,2005,IN,1,,FRHT,HUMAN,Not',
#   'Applicable,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2013,11389103,SUBURBAN,Not',
#   'Entered,Parked,Not',
#   'Entered,North,Not',
#   'Entered,2003,GA,1,,FORD,VEHICLE,Other*,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,1FMPU17L93L'],
#  ['2013,11280549,SUBURBAN,Not',
#   'Entered,Stopped',
#   'in',
#   'Traffic,Not',
#   'Entered,South,Not',
#   'Entered,1994,FL,2,,JEEP,HUMAN,Not',
#   'Applicable,HUMAN,Not',
#   'Applicable,Not',
#   'Entered,'],
#  ['2013,10945793,2',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,West,Not',
#   'Entered,2009,GA,1,,SCIO,HUMAN,Following',
#   'Too',
#   'Closely,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2013,11335010,MOTORCYCLE,MOTORCYCLE,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,East,Gas,2006,NY,2,1,KAWAS,HUMAN,Not',
#   'Applicable,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,JKBVNME156A'],
#  ['2013,11169713,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,South,Not',
#   'Entered,1997,NY,1,,TOYT,HUMAN,Driver',
#   'Inattention/Distraction*,HUMAN,Following',
#   'Too',
#   'Closely,Not',
#   'Applicable,4T1BG22K7VU'],
#  ['2013,11462058,DELIVERY',
#   'TRUCK,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,North,Not',
#   'Entered,1988,US,1,,GRUM,VEHICLE,Other*,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,1GBBS10E3K2'],
#  ['2013,11542677,PICKUP',
#   'TRUCK,Not',
#   'Entered,Slowing',
#   'or',
#   'Stopping,Not',
#   'Entered,West,Not',
#   'Entered,2007,PA,1,,DODG,ENVMT,Obstruction/',
#   'Debris,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2013,11180902,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Making',
#   'Left',
#   'Turn,Not',
#   'Entered,North,Not',
#   'Entered,2003,IL,3,,JAGU,HUMAN,Failure',
#   'to',
#   'Yield',
#   'Right-of-Way,HUMAN,Turning',
#   'Improperly,Not',
#   'Applicable,'],
#  ['2013,11185367,VAN',
#   'TRUCK,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,South,Not',
#   "Entered,2013,FL,2,,CHRY,ENVMT,Animal's",
#   'Action,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2013,11085160,SUBURBAN,Not',
#   'Entered,Making',
#   'Left',
#   'Turn,Not',
#   'Entered,West,Not',
#   'Entered,2010,ON,1,,TOYT,HUMAN,Not',
#   'Applicable,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2013,11556751,PICKUP',
#   'TRUCK,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,South,Not',
#   'Entered,2004,NJ,1,,CHEV,HUMAN,Unsafe',
#   'Speed,ENVMT,Pavement',
#   'Slippery,"Earth',
#   'Embankment/Rock',
#   'Cut/Ditch,',
#   'Collision',
#   'With',
#   'Fixed',
#   'Object",1GCDT136448'],
#  ['2013,11455491,SUBURBAN,Not',
#   'Entered,Slowing',
#   'or',
#   'Stopping,Not',
#   'Entered,North,Not',
#   'Entered,2010,PA,1,,TOYT,HUMAN,Not',
#   'Applicable,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2013,11620035,BUS',
#   '(OMNIBUS),Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,South,Not',
#   'Entered,2013,NY,1,,MCIN,HUMAN,Following',
#   'Too',
#   'Closely,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,2MG3JM8A7DW'],
#  ['2013,11231725,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Making',
#   'Left',
#   'Turn,Not',
#   'Entered,Southwest,Not',
#   'Entered,2009,PA,2,,KIA,HUMAN,Not',
#   'Applicable,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2013,11734632,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,East,Not',
#   'Entered,2010,NJ,1,,CHRY,HUMAN,Following',
#   'Too',
#   'Closely,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2013,11041621,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,North,Not',
#   'Entered,2002,NY,1,,CHEV,HUMAN,Illness,HUMAN,Not',
#   'Applicable,"Tree,',
#   'Collision',
#   'With',
#   'Fixed',
#   'Object",'],
#  ['2013,11477119,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Slowing',
#   'or',
#   'Stopping,Not',
#   'Entered,North,Not',
#   'Entered,2007,IN,1,,VOLK,HUMAN,Following',
#   'Too',
#   'Closely,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2013,11346728,OTHER',
#   'VEHICLE,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,West,Not',
#   'Entered,2001,PA,1,,CHEV,HUMAN,Following',
#   'Too',
#   'Closely,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2013,11546612,PICKUP',
#   'TRUCK,Not',
#   'Entered,Making',
#   'Left',
#   'Turn,Not',
#   'Entered,North,Not',
#   'Entered,2004,MA,1,,TOYT,HUMAN,Not',
#   'Applicable,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2013,11591378,PICKUP',
#   'TRUCK,Not',
#   'Entered,Parked,Not',
#   'Entered,South,Not',
#   'Entered,2000,NC,2,,FORD,HUMAN,Not',
#   'Applicable,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,1ETBX18H8YN'],
#  ['2013,11085833,SUBURBAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,East,Not',
#   'Entered,2011,CT,1,,HOND,HUMAN,Following',
#   'Too',
#   'Closely,HUMAN,Following',
#   'Too',
#   'Closely,Not',
#   'Applicable,'],
#  ['2013,11131133,POLICE',
#   'VEHICLE,Not',
#   'Entered,Stopped',
#   'in',
#   'Traffic,Not',
#   'Entered,South,Not',
#   'Entered,2012,NY,1,,CHEV,HUMAN,Not',
#   'Applicable,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,3VWCC21C0YM'],
#  ['2013,11253088,BICYCLIST,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,West,Not',
#   'Entered,,,1,,,HUMAN,Pedestrian/Bicyclist',
#   'Error/Confusion,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2013,11603346,SUBURBAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,West,Not',
#   'Entered,2002,NY,2,,HYUN,HUMAN,Not',
#   'Applicable,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,KM8SC73D82U'],
#  ['2013,10989070,TRACTOR,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,West,Not',
#   "Entered,2011,IN,1,,VOLV,ENVMT,Animal's",
#   'Action,HUMAN,Not',
#   'Applicable,"Guide',
#   'Rail',
#   '-',
#   'End,',
#   'Collision',
#   'With',
#   'Fixed',
#   'Object",4V4NC9EJXBN'],
#  ['2013,11622893,SUBURBAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,North,Not',
#   'Entered,2003,NJ,1,,CHEV,HUMAN,Unsafe',
#   'Speed,ENVMT,Pavement',
#   'Slippery,Not',
#   'Applicable,'],
#  ['2013,11196182,2',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Backing,Not',
#   'Entered,South,Not',
#   'Entered,2014,NJ,1,,AUDI,HUMAN,Backing',
#   'Unsafely,HUMAN,Driver',
#   'Inattention/Distraction*,Not',
#   'Applicable,WAUCFAFR3BA'],
#  ['2013,11222679,PICKUP',
#   'TRUCK,PASSENGER',
#   'OR',
#   'SUBURBAN,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,South,Gas,2003,NY,1,10,FORD,HUMAN,Unsafe',
#   'Speed,ENVMT,Pavement',
#   'Slippery,"Overturned,',
#   'Non-Collision",1FTNX21S83E'],
#  ['2013,11626941,PICKUP',
#   'TRUCK,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,South,Not',
#   'Entered,2008,NH,1,,TOYT,HUMAN,Not',
#   'Applicable,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,5TEUU42N78Z'],
#  ['2013,11194330,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Making',
#   'Left',
#   'Turn,Not',
#   'Entered,Southeast,Not',
#   'Entered,2005,NY,1,,JAGU,HUMAN,Driver',
#   'Inattention/Distraction*,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,'],
#  ['2013,11558377,TRACTOR,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,West,Not',
#   'Entered,2012,NC,1,,INTL,ENVMT,Obstruction/',
#   'Debris,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,1HSHWSJN8CJ'],
#  ['2013,10979189,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,West,Not',
#   'Entered,2007,OH,1,,FORD,HUMAN,Unsafe',
#   'Speed,ENVMT,Pavement',
#   'Slippery,Not',
#   'Applicable,2FMDK36C47B'],
#  ['2013,11172280,4',
#   'DOOR',
#   'SEDAN,Not',
#   'Entered,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,East,Not',
#   'Entered,2011,NY,1,,NISS,HUMAN,Driver',
#   'Inattention/Distraction*,HUMAN,Not',
#   'Applicable,Not',
#   'Applicable,1N4AL2AP3BN'],
#  ['2012,11020523,MOTORCYCLE,MOTORCYCLE,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,South,Gas,2006,NY,1,1,YAMAH,HUMAN,Unknown,HUMAN,Not',
#   'Entered,Not',
#   'Entered,LPRSA30A06A'],
#  ['2012,10062965,PICKUP',
#   'TRUCK,COMMERCIAL,Going',
#   'Straight',
#   'Ahead,Not',
#   'Entered,South,Gas,1999,NY,2,10,FORD,HUMAN,Driver',
#   'Inattention/Distraction*,HUMAN,Following',
#   'Too',
#   'Closely,Not',
#   'Applicable,1FTSX31S4XE'],
#  ['2013,11568750,PICKUP',
#   'TRUCK,Not',
#   'Entered,Starting',
#   'from',
#   'Parking,Not',
#   'Entered,West,Not',
#   'Entered,1997,CT,2,,FORD,HUMAN,Driver',
#   'Inattention/Distraction*,HUMAN,Passenger',
#   'Distraction,Not',
#   'Applicable,']]

# %% [markdown]
# Create a list of candidate itemsets of length k
#
# Scan the dataset to see if each itemset is frequent
#
# Keep frequent itemsets to create itemsets of length k+1

# %%
def aprioriGen(Lk, k): #creates Ck
    retList = []
    lenLk = len(Lk)
    for i in range(lenLk):
        for j in range(i+1, lenLk): 
            L1 = list(Lk[i])[:k-2]; L2 = list(Lk[j])[:k-2]
            L1.sort(); L2.sort()
            if L1==L2: #if first k-2 elements are equal
                retList.append(Lk[i] | Lk[j]) #set union
    return retList

# %%
def apriori_alg(dataSet, minSupport = 0.5):
    C1 = createC1(dataSet)
    D = list(map(set, dataSet))
    L1, supportData = scanD(D, C1, minSupport)
    L = [L1]
    k = 2
    while (len(L[k-2]) > 0):
        Ck = aprioriGen(L[k-2], k)
        Lk, supK = scanD(D, Ck, minSupport)#scan DB to get Lk
        supportData.update(supK)
        L.append(Lk)
        k += 1
    return L, supportData

# %%
def generateRules(L, supportData, minConf=0.7):  #supportData is a dict coming from scanD
    bigRuleList = []
    for i in range(1, len(L)):#only get the sets with two or more items
        for freqSet in L[i]:
            H1 = [frozenset([item]) for item in freqSet]
            if (i > 1):
                rulesFromConseq(freqSet, H1, supportData, bigRuleList, minConf)
            else:
                calcConf(freqSet, H1, supportData, bigRuleList, minConf)
    return bigRuleList

# %% [markdown]
# The main function is apriori(); it calls aprioriGen() to create candidate itemsets: Ck.
#
# The function aprioriGen() will take a list of frequent itemsets, Lk, and the size of the itemsets, k, to produce Ck. For example, it will take the itemsets {0}, {1}, {2} and so on and produce {0,1} {0,2}, and {1,2}.
#
# The sets are combined using the set union, which is the | symbol in Python

# %%
def createC1(dataSet):
    C1 = []
    for transaction in dataSet:
        for item in transaction:
            if not [item] in C1:
                C1.append([item])
                
    C1.sort()
    return list(map(frozenset, C1))#use frozen set so we
                            #can use it as a key in a dict

# %% [markdown]
# This function takes three arguments: a dataset, Ck, a list of candidate sets, and minSupport, which is the minimum support you’re interested in. This is the function you’ll use to generate L1 from C1. Additionally, this function returns a dictionary with support values.

# %%
def scanD(D, Ck, minSupport):
    ssCnt = {}
    for tid in D:
        for can in Ck:
            if can.issubset(tid):
                if not can in ssCnt: ssCnt[can]=1
                else: ssCnt[can] += 1
    numItems = float(len(D))
    retList = []
    supportData = {}
    for key in ssCnt:
        support = ssCnt[key]/numItems
        if support >= minSupport:
            retList.insert(0,key)
        supportData[key] = support
    return retList, supportData

# %% [markdown]
# Mining association rules from frequent item sets
# ---------------------------------------------------
#
# To find association rules, we first start with a frequent itemset. We know this set of items is unique, but we want to see if there is anything else we can get out of these items. One item or one set of items can imply another item.
#
# generateRules(), is the main command, which calls the other two.
#
# The generateRules() function takes three inputs: a list of frequent itemsets, a dictionary of support data for those itemsets, and a minimum confidence threshold. It’s going to generate a list of rules with confidence values that we can sort through later.

# %%
def calcConf(freqSet, H, supportData, brl, minConf=0.7):
    prunedH = [] #create new list to return
    for conseq in H:
        conf = supportData[freqSet]/supportData[freqSet-conseq] #calc confidence
        if conf >= minConf: 
            print (freqSet-conseq,'-->',conseq,'conf:',conf)
            brl.append((freqSet-conseq, conseq, conf))
            prunedH.append(conseq)
    return prunedH

# %% [markdown]
# calcConf() calculates the confidence of the rule and then find out the which rules meet the minimum confidence

# %%
def rulesFromConseq(freqSet, H, supportData, brl, minConf=0.7):
    m = len(H[0])
    if (len(freqSet) > (m + 1)): #try further merging
        Hmp1 = aprioriGen(H, m+1)#create Hm+1 new candidates
        Hmp1 = calcConf(freqSet, Hmp1, supportData, brl, minConf)
        if (len(Hmp1) > 1):    #need at least two sets to merge
            rulesFromConseq(freqSet, Hmp1, supportData, brl, minConf)

# %% [markdown]
# rulesFromConseq() generates more association rules from our initial dataset. This takes a frequent itemset and H, which is a list of items that could be on the right-hand side of a rule

# %%
L,suppData= apriori_alg(dataset, minSupport=0.3)
suppData
# Out:
# {frozenset({'Entered,Northwest,Not'}): 0.03,
#  frozenset({'Entered,2000,NJ,1,,FRHT,HUMAN,Unsafe'}): 0.01,
#  frozenset({'2013,11622893,SUBURBAN,Not'}): 0.01,
#  frozenset({'Entered,2006,CT,1,,TOYT,HUMAN,Failure'}): 0.01,
#  frozenset({'Applicable,"Guide'}): 0.01,
#  frozenset({'Applicable,2G1WB5EK7B1'}): 0.01,
#  frozenset({"Entered,2010,PA,1,,NISS,ENVMT,Animal's"}): 0.01,
#  frozenset({'Applicable,2MG3JM8A7DW'}): 0.01,
#  frozenset({'TRUCK,COMMERCIAL,Stopped'}): 0.01,
#  frozenset({'Entered,2007,CT,1,,VOLV,ENVMT,View'}): 0.01,
#  frozenset({'2013,11161588,4'}): 0.01,
#  frozenset({'Closely,Not'}): 0.04,
#  frozenset({'Occupants,Engine'}): 0.01,
#  frozenset({'Entered,2007,OH,1,,FORD,HUMAN,Unsafe'}): 0.01,
#  frozenset({'DOOR', 'SEDAN,Not'}): 0.44,
#  frozenset({'Entered,South,Gas,2003,NY,1,10,FORD,HUMAN,Unsafe'}): 0.01,
#  frozenset({'Applicable,1ETBX18H8YN'}): 0.01,
#  frozenset({'Entered,2013,NJ,1,,FORD,HUMAN,Driver'}): 0.01,
#  frozenset({'2013,10950672,SUBURBAN,Not'}): 0.01,
#  frozenset({'Entered,2011,CT,1,,HOND,HUMAN,Following'}): 0.01,
#  frozenset({'Entered,2004,NJ,1,,CHEV,HUMAN,Unsafe'}): 0.01,
#  frozenset({'Entered,2010,PA,1,,TOYT,HUMAN,Not'}): 0.01,
#  frozenset({'Applicable,', 'Straight'}): 0.25,
#  frozenset({'Applicable,2FMDK36C47B'}): 0.01,
#  frozenset({'2013,11558377,TRACTOR,Not'}): 0.01,
#  frozenset({'Object",'}): 0.02,
#  frozenset({'Entered,Stopped'}): 0.03,
#  frozenset({'2013,11132317,SUBURBAN,Not'}): 0.01,
#  frozenset({'Entered,2011,ME,1,,CADI,HUMAN,Prescription'}): 0.01,
#  frozenset({'2013,10809401,4'}): 0.01,
#  frozenset({'2013,11386243,TRACTOR,Not'}): 0.01,
#  frozenset({'Applicable,3N1AB61E38L'}): 0.01,
#  frozenset({'2013,11388795,4'}): 0.01,
#  frozenset({'Right-of-Way,HUMAN,Not'}): 0.06,
#  frozenset({'Prior'}): 0.01,
#  frozenset({'Inattention/Distraction*,Not'}): 0.03,
#  frozenset({'2013,10989070,TRACTOR,Not'}): 0.01,
#  frozenset({"Applicable,ENVMT,Animal's"}): 0.01,
#  frozenset({'2013,11194330,4'}): 0.01,
#  frozenset({'2013,10890741,SUBURBAN,Not'}): 0.01,
#  frozenset({'Right-of-Way,HUMAN,Turning'}): 0.01,
#  frozenset({'2013,11085833,SUBURBAN,Not'}): 0.01,
#  frozenset({'2013,11386643,MOTORCYCLE,Not'}): 0.01,
#  frozenset({'Applicable,4T1BG22K7VU'}): 0.01,
#  frozenset({'2012,10001283,4'}): 0.01,
#  frozenset({'Entered,Starting'}): 0.01,
#  frozenset({'Entered,2007,NY,1,,TOYT,ENVMT,Pavement'}): 0.01,
#  frozenset({'Entered,2013,NY,1,,MCIN,HUMAN,Following'}): 0.01,
#  frozenset({'Entered,2013,NY,2,,HYUN,HUMAN,Following'}): 0.01,
#  frozenset({'Improperly,HUMAN,Not'}): 0.01,
#  frozenset({'Straight'}): 0.63,
#  frozenset({"Entered,2011,IN,1,,VOLV,ENVMT,Animal's"}): 0.01,
#  frozenset({'2013,11556751,PICKUP'}): 0.01,
#  frozenset({'Entered,2004,SC,1,,FORD,HUMAN,Following'}): 0.01,
#  frozenset({'Entered,2012,NY,1,,CHEV,HUMAN,Not'}): 0.01,
#  frozenset({'Entered,,,1,,,HUMAN,Unknown,HUMAN,Unknown,Not'}): 0.01,
#  frozenset({'Applicable,1N4AL2AP3BN'}): 0.01,
#  frozenset({'Obstructed/Limited,"Other'}): 0.01,
#  frozenset({'Too'}): 0.16,
#  frozenset({'Entered,2012,NJ,4,,AUDI,VEHICLE,Other*,HUMAN,Not'}): 0.01,
#  frozenset({'2013,11542677,PICKUP'}): 0.01,
#  frozenset({'Ahead,Not', 'Applicable,Not', 'Straight'}): 0.39,
#  frozenset({'Applicable,1FDAF56Y38E'}): 0.01,
#  frozenset({'Closely,HUMAN,Following'}): 0.01,
#  frozenset({'Traffic,Not'}): 0.05,
#  frozenset({'TRUCK,POLITICAL'}): 0.01,
#  frozenset({'Applicable,Not', 'SEDAN,Not', 'Straight'}): 0.16,
#  frozenset({'Speed,HUMAN,Not'}): 0.01,
#  frozenset({'With'}): 0.05,
#  frozenset({'Entered,West,Not'}): 0.18,
#  frozenset({'Applicable,3C4FY48B05T'}): 0.01,
#  frozenset({'2013,11549669,4'}): 0.01,
#  frozenset({'Obstructed/Limited,HUMAN,Failure'}): 0.01,
#  frozenset({'Entered,Backing,Not'}): 0.02,
#  frozenset({'2012,10742629,DUMP,Not'}): 0.01,
#  frozenset({'Lanes,Not'}): 0.01,
#  frozenset({'Disregarded,HUMAN,Not'}): 0.02,
#  frozenset({'2013,11169713,4'}): 0.01,
#  frozenset({'Entered,East,None,2001,NY,1,0,DODGE,HUMAN,Not'}): 0.01,
#  frozenset({'Applicable,1FUJBBCK39L'}): 0.01,
#  frozenset({'Entered,2003,GA,1,,FORD,VEHICLE,Other*,HUMAN,Not'}): 0.01,
#  frozenset({'2013,10999745,4'}): 0.01,
#  frozenset({'Axles'}): 0.01,
#  frozenset({'2013,11299375,4'}): 0.01,
#  frozenset({'Applicable,1FTWX31Y28E'}): 0.01,
#  frozenset({'2013,11256149,2'}): 0.01,
#  frozenset({'Entered,South,None,2006,NY,1,0,ME/BE,HUMAN,Following'}): 0.01,
#  frozenset({'With",4KAMGABMX3A'}): 0.01,
#  frozenset({'OR'}): 0.01,
#  frozenset({'Applicable,Not', 'DOOR', 'SEDAN,Not'}): 0.31,
#  frozenset({'2013,11034074,Not'}): 0.01,
#  frozenset({'Inattention/Distraction*,HUMAN,Not'}): 0.04,
#  frozenset({'2013,11481774,4'}): 0.01,
#  frozenset({'2013,11455491,SUBURBAN,Not'}): 0.01,
#  frozenset({'2'}): 0.01,
#  frozenset({'Entered,2005,NY,1,,JAGU,HUMAN,Driver'}): 0.01,
#  frozenset({'Travel,Fuel'}): 0.01,
#  frozenset({'2013,11734632,4'}): 0.01,
#  frozenset({'Fixed'}): 0.05,
#  frozenset({'Slippery,ENVMT,View'}): 0.01,
#  frozenset({'Applicable,1GBBS10E3K2'}): 0.01,
#  frozenset({'2013,10945793,2'}): 0.01,
#  frozenset({'SUBDIVISION,Stopped'}): 0.01,
#  frozenset({'Applicable,4T1BF22K3YU'}): 0.01,
#  frozenset({'VIN'}): 0.01,
#  frozenset({'Entered,2004,CT,1,,FORD,HUMAN,Alcohol'}): 0.01,
#  frozenset({'Applicable,JTJBM7FX8C5'}): 0.01,
#  frozenset({"Entered,2007,MS,1,,CHEV,ENVMT,Animal's"}): 0.01,
#  frozenset({'2013,11280549,SUBURBAN,Not'}): 0.01,
#  frozenset({'Entered,2009,MN,1,,VOLV,HUMAN,Following'}): 0.01,
#  frozenset({'Entered,2008,GA,1,,LEXS,HUMAN,Driver'}): 0.01,
#  frozenset({'Entered,JTHBE96S380'}): 0.01,
#  frozenset({'2013,11591378,PICKUP'}): 0.01,
#  frozenset({'Entered,1988,US,1,,GRUM,VEHICLE,Other*,HUMAN,Not'}): 0.01,
#  frozenset({'Class,Action'}): 0.01,
#  frozenset({'2013,10949728,SUBURBAN,Not'}): 0.01,
#  frozenset({'Non-Collision",2T1BR32E35C'}): 0.01,
#  frozenset({'Entered,2007,NJ,1,,HA/DA,HUMAN,Unknown,HUMAN,Not'}): 0.01,
#  frozenset({'Applicable,', 'SEDAN,Not'}): 0.21,
#  frozenset({'2013,11626941,PICKUP'}): 0.01,
#  frozenset({'Distraction,Not'}): 0.01,
#  frozenset({'Ahead,Not', 'DOOR'}): 0.28,
#  frozenset({'Slippery,HUMAN,Not'}): 0.02,
#  frozenset({'Entered,'}): 0.04,
#  frozenset({'Entered,2010,FL,1,,FORD,HUMAN,Turning'}): 0.01,
#  frozenset({'Entered,2007,IN,1,,VOLK,HUMAN,Following'}): 0.01,
#  frozenset({'Entered,2007,PA,1,,DODG,ENVMT,Obstruction/'}): 0.01,
#  frozenset({'2013,10931825,4'}): 0.01,
#  frozenset({'Entered,2006,NJ,3,,DODG,ENVMT,Pavement'}): 0.01,
#  frozenset({'Improper,HUMAN,Not'}): 0.01,
#  frozenset({'Entered,Southwest,None,2001,NY,1,0,MAC,HUMAN,Unsafe'}): 0.01,
#  frozenset({'Entered,2002,NY,2,,HYUN,HUMAN,Not'}): 0.01,
#  frozenset({'2013,11544573,4'}): 0.01,
#  frozenset({'Entered,Overtaking/Passing,Not'}): 0.01,
#  frozenset({'Applicable,1XKWD89X23J'}): 0.01,
#  frozenset({'Stopping,Not'}): 0.07,
#  frozenset({'Entered,2013,VA,1,,DODG,HUMAN,Unsafe'}): 0.01,
#  frozenset({'2013,11582492,SUBURBAN,Not'}): 0.01,
#  frozenset({'2013,11502543,TRACTOR,Not'}): 0.01,
#  frozenset({'Entered,2012,NJ,1,,CHEV,HUMAN,Not'}): 0.01,
#  frozenset({'Applicable,3VWCC21C0YM'}): 0.01,
#  frozenset({'Entered,South,Gas,2006,NY,1,1,YAMAH,HUMAN,Unknown,HUMAN,Not'}): 0.01,
#  frozenset({'Applicable,1YVGF22D3W5'}): 0.01,
#  frozenset({'2012,10062965,PICKUP'}): 0.01,
#  frozenset({'Entered,East,Gas,2006,NY,2,1,KAWAS,HUMAN,Not'}): 0.01,
#  frozenset({'Ahead,Not', 'Applicable,Not', 'Entered,Going'}): 0.36,
#  frozenset({'Entered,2014,NJ,1,,AUDI,HUMAN,Backing'}): 0.01,
#  frozenset({'Entered,2008,CT,0,,HYUN,HUMAN,Not'}): 0.01,
#  frozenset({'Applicable,Not', 'Straight'}): 0.39,
#  frozenset({'2012,11020523,MOTORCYCLE,MOTORCYCLE,Going'}): 0.01,
#  frozenset({'Applicable,1FMPU17L93L'}): 0.01,
#  frozenset({'Entered,2009,PA,2,,KIA,HUMAN,Not'}): 0.01,
#  frozenset({'2013,10979189,4'}): 0.01,
#  frozenset({'2013,11253088,BICYCLIST,Not'}): 0.01,
#  frozenset({'Applicable,1FTSX31S4XE'}): 0.01,
#  frozenset({'Entered,Changing'}): 0.01,
#  frozenset({'Applicable,HUMAN,Not', 'Applicable,Not', 'DOOR'}): 0.14,
#  frozenset({'Applicable,1GBBS10EXK2'}): 0.01,
#  frozenset({'Right-of-Way,"Earth'}): 0.01,
#  frozenset({'Description,Contributing'}): 0.01,
#  frozenset({'2013,11153609,4'}): 0.01,
#  frozenset({'Type,Vehicle'}): 0.01,
#  frozenset({'Motor'}): 0.02,
#  frozenset({'Applicable,WAUCFAFR3BA'}): 0.01,
#  frozenset({'Control'}): 0.02,
#  frozenset({'ID,Vehicle'}): 0.01,
#  frozenset({'Entered,2012,NC,1,,INTL,ENVMT,Obstruction/'}): 0.01,
#  frozenset({'SEDAN,DEALER,Going'}): 0.03,
#  frozenset({'Applicable,HUMAN,Not', 'DOOR'}): 0.14,
#  frozenset({'Entered,2010,ON,1,,TOYT,HUMAN,Not'}): 0.01,
#  frozenset({'Entered,Making'}): 0.13,
#  frozenset({'Applicable,1HSHWSJN8CJ'}): 0.01,
#  frozenset({'Bus,Direction'}): 0.01,
#  frozenset({'2013,11179199,4'}): 0.01,
#  frozenset({'2013,11336198,4'}): 0.01,
#  frozenset({'Entered,2009,NY,1,,SPTN,HUMAN,Passing'}): 0.01,
#  frozenset({'Entered,2009,OK,1,,FRHT,HUMAN,Driver'}): 0.01,
#  frozenset({'Entered,1994,FL,2,,JEEP,HUMAN,Not'}): 0.01,
#  frozenset({'Changing,HUMAN,Passing'}): 0.01,
#  frozenset({'Vehicle,'}): 0.02,
#  frozenset({"Entered,2013,FL,2,,CHRY,ENVMT,Animal's"}): 0.01,
#  frozenset({'2013,11457986,SUBURBAN,Not'}): 0.01,
#  frozenset({'Slippery,HUMAN,Unsafe'}): 0.01,
#  frozenset({'2013,11560358,PICKUP'}): 0.01,
#  frozenset({'Applicable,Not', 'Entered,Going', 'SEDAN,Not'}): 0.16,
#  frozenset({'2013,11572398,4'}): 0.01,
#  frozenset({'Entered,2003,PA,1,,KW,HUMAN,Unknown,HUMAN,Not'}): 0.01,
#  frozenset({'2013,11595087,4'}): 0.01,
#  frozenset({'Entered,HUMAN,Not'}): 0.01,
#  frozenset({'Entered,2006,AK,4,,TOYT,HUMAN,Unsafe'}): 0.01,
#  frozenset({'2013,11376104,SUBURBAN,Not'}): 0.01,
#  frozenset({'Entered,2013,IL,2,,FORD,HUMAN,Not'}): 0.01,
#  frozenset({'Applicable,Not', 'DOOR', 'Straight'}): 0.18,
#  frozenset({'Rage,HUMAN,Failure'}): 0.01,
#  frozenset({'2013,11324702,4'}): 0.01,
#  frozenset({'Lane'}): 0.04,
#  frozenset({'1,Contributing'}): 0.01,
#  frozenset({'Ahead,Not', 'Applicable,HUMAN,Not'}): 0.12,
#  frozenset({'Applicable,1FMFU18526L'}): 0.01,
#  frozenset({'2013,10861000,VAN'}): 0.01,
#  frozenset({'Entered,2004,MA,1,,TOYT,HUMAN,Not'}): 0.01,
#  frozenset({'2012,10454932,4'}): 0.01,
#  frozenset({'Entered,2008,NH,1,,TOYT,HUMAN,Not'}): 0.01,
#  frozenset({'DOOR', 'Straight'}): 0.28,
#  frozenset({'2012,11143993,TRACTOR,SEMI-TRAILER,Making'}): 0.01,
#  frozenset({'Entered,Southwest,Not'}): 0.01,
#  frozenset({'VEHICLE,Not'}): 0.04,
#  frozenset({'Ahead,Not', 'Applicable,Not', 'Entered,Going', 'Straight'}): 0.36,
#  frozenset({'Applicable,JKBVNME156A'}): 0.01,
#  frozenset({'1'}): 0.01,
#  frozenset({'Entered,2010,NJ,2,,TOYT,HUMAN,Not'}): 0.01,
#  frozenset({'Entered,1998,NY,0,,MAZD,HUMAN,Not'}): 0.01,
#  frozenset({'Collision'}): 0.07,
#  frozenset({'Factor'}): 0.01,
#  frozenset({'LIMITED'}): 0.01,
#  frozenset({'Slippery,Not'}): 0.03,
#  frozenset({'Entered,Not'}): 0.05,
#  frozenset({'Inattention/Distraction*,HUMAN,Passenger'}): 0.01,
#  frozenset({'2013,11346728,OTHER'}): 0.01,
#  frozenset({'Entered,2010,NY,1,,HONDA,HUMAN,Following'}): 0.01,
#  frozenset({'2,Contributing'}): 0.01,
#  frozenset({'Ahead,Not', 'Entered,Going'}): 0.56,
#  frozenset({'Entered,Parked,Not'}): 0.04,
#  frozenset({'Applicable,5TEUU42N78Z'}): 0.01,
#  frozenset({'Entered,2005,NY,1,,TOYT,ENVMT,Pavement'}): 0.01,
#  frozenset({'2013,11495022,4'}): 0.01,
#  frozenset({'Entered,2005,PA,3,,CHRY,HUMAN,Aggressive'}): 0.01,
#  frozenset({'Asleep,Not'}): 0.01,
#  frozenset({'2013,11196182,2'}): 0.01,
#  frozenset({'Year,Case'}): 0.01,
#  frozenset({'2013,11526173,FIRE'}): 0.01,
#  frozenset({'Entered,Northeast,Not'}): 0.01,
#  frozenset({'2013,11085160,SUBURBAN,Not'}): 0.01,
#  frozenset({'Body'}): 0.01,
#  frozenset({'Applicable,', 'Applicable,Not'}): 0.35,
#  frozenset({'2013,11389103,SUBURBAN,Not'}): 0.01,
#  frozenset({'Entered,LPRSA30A06A'}): 0.01,
#  frozenset({'2012,10459509,MOTORCYCLE,CLASS'}): 0.01,
#  frozenset({'Yield'}): 0.08,
#  frozenset({'Applicable,1FMZU63K44U'}): 0.01,
#  frozenset({'2012,10915394,4'}): 0.01,
#  frozenset({'TRUCK,COMMERCIAL,Going'}): 0.01,
#  frozenset({'Entered,2012,VA,1,,NISS,HUMAN,Not'}): 0.01,
#  frozenset({'TRUCK,PASSENGER'}): 0.01,
#  frozenset({'2013,10831549,POLICE'}): 0.01,
#  frozenset({'Entered,2000,CT,1,,TOYT,HUMAN,Following'}): 0.01,
#  frozenset({'Truck'}): 0.01,
#  frozenset({"Entered,East,None,2012,NY,1,0,CHRY,ENVMT,Animal's"}): 0.01,
#  frozenset({'Parking,Not'}): 0.01,
#  frozenset({'DOOR'}): 0.47,
#  frozenset({'DOOR', 'Entered,Going'}): 0.25,
#  frozenset({'TRUCK,Not'}): 0.13,
#  frozenset({'Entered,South,Gas,1999,NY,2,10,FORD,HUMAN,Driver'}): 0.01,
#  frozenset({'2013,11592276,FLAT'}): 0.01,
#  frozenset({'2013,11222679,PICKUP'}): 0.01,
#  frozenset({'2013,11395761,TRACTOR,Not'}): 0.01,
#  frozenset({'Entered,South,Not'}): 0.22,
#  frozenset({'Applicable,Not'}): 0.68,
#  frozenset({'Applicable,Not', 'DOOR', 'Entered,Going'}): 0.16,
#  frozenset({'Accident,Type'}): 0.01,
#  frozenset({'Ahead,Not'}): 0.63,
#  frozenset({'Entered,2006,NY,1,,FORD,HUMAN,Not'}): 0.01,
#  frozenset({'2013,11620035,BUS'}): 0.01,
#  frozenset({'Registration,Number'}): 0.01,
#  frozenset({'2013,11610502,4'}): 0.01,
#  frozenset({'Inattention/Distraction*,HUMAN,Following'}): 0.03,
#  frozenset({'Applicable,', 'DOOR'}): 0.23,
#  frozenset({'Slippery,"Overturned,'}): 0.01,
#  frozenset({'Action,HUMAN,Not'}): 0.06,
#  frozenset({'Entered,2012,NJ,1,,LEXS,HUMAN,Failure'}): 0.01,
#  frozenset({'Entered,2013,TN,1,,TOYT,HUMAN,Failure'}): 0.01,
#  frozenset({'2013,11477119,4'}): 0.01,
#  frozenset({'Improperly,Not'}): 0.01,
#  frozenset({'Turn,Not'}): 0.15,
#  frozenset({'2013,11180902,4'}): 0.01,
#  frozenset({'Entered,2001,PA,1,,CHEV,HUMAN,Following'}): 0.01,
#  frozenset({'2013,10944884,DELIVERY'}): 0.01,
#  frozenset({'Year,State'}): 0.01,
#  frozenset({'Applicable,"Overturned,'}): 0.01,
#  frozenset({'USE'}): 0.01,
#  frozenset({'Object",1GCDT136448'}): 0.01,
#  frozenset({'Applicable,"Other'}): 0.01,
#  frozenset({'Entered,Slowing'}): 0.07,
#  frozenset({'2013,11330798,4'}): 0.01,
#  frozenset({'Entered,Unknown,Not'}): 0.01,
#  frozenset({'Entered,2011,NY,1,,NISS,HUMAN,Driver'}): 0.01,
#  frozenset({'Applicable,Not', 'DOOR'}): 0.33,
#  frozenset({'Unsafely,HUMAN,Driver'}): 0.02,
#  frozenset({'Entered,Southeast,Not'}): 0.04,
#  frozenset({'Entered,2013,MD,1,,FORD,HUMAN,Following'}): 0.01,
#  frozenset({'Entered,2003,PA,1,,INTE,ENVMT,Pavement'}): 0.01,
#  frozenset({'Entered,East,Gas,2008,NY,2,10,FORD,HUMAN,Not'}): 0.01,
#  frozenset({'Make,Contributing'}): 0.01,
#  frozenset({'Right,Not'}): 0.01,
#  frozenset({'Changing,Not'}): 0.01,
#  frozenset({'Applicable,5TBET34116S'}): 0.01,
#  frozenset({'Entered,2009,GA,1,,SCIO,HUMAN,Following'}): 0.01,
#  frozenset({'Entered,2003,NJ,1,,CHEV,HUMAN,Unsafe'}): 0.01,
#  frozenset({'Speed,"Tree,'}): 0.01,
#  frozenset({'Error/Confusion,HUMAN,Not'}): 0.01,
#  frozenset({'Applicable,HUMAN,Not', 'Applicable,Not', 'Straight'}): 0.12,
#  frozenset({'2013,10950427,4'}): 0.01,
#  frozenset({'Entered,2008,CT,1,,NISS,HUMAN,Not'}): 0.01,
#  frozenset({'2013,11185367,VAN'}): 0.01,
#  frozenset({'Entered,2005,PA,1,,TOYT,HUMAN,Traffic'}): 0.01,
#  frozenset({'2013,11308219,SUBURBAN,Not'}): 0.01,
#  frozenset({'2013,11546612,PICKUP'}): 0.01,
#  frozenset({'Applicable,HUMAN,Not', 'Straight'}): 0.12,
#  frozenset({'BED'}): 0.01,
#  frozenset({'Type,Partial'}): 0.01,
#  frozenset({'Medication,HUMAN,Unsafe'}): 0.01,
#  frozenset({'Applicable,1FADP3F28DL'}): 0.01,
#  frozenset({'2013,11041621,4'}): 0.01,
#  frozenset({'2013,11423026,4'}): 0.01,
#  frozenset({'Embankment/Rock'}): 0.02,
#  frozenset({'Entered,2007,NY,2,,FORD,HUMAN,Failure'}): 0.01,
#  frozenset({'Entered,1994,NJ,1,,HOND,HUMAN,Not'}): 0.01,
#  frozenset({'2013,11572845,4'}): 0.01,
#  frozenset({'Entered,2003,IL,3,,JAGU,HUMAN,Failure'}): 0.01,
#  frozenset({'Entered,2006,MA,5,,FORD,HUMAN,Not'}): 0.01,
#  frozenset({'Applicable,4S7AU2F969C'}): 0.01,
#  frozenset({'to'}): 0.1,
#  frozenset({'Applicable,'}): 0.45,
#  frozenset({'Entered,2005,NY,4,,TOYT,HUMAN,Not'}): 0.01,
#  frozenset({'Applicable,HUMAN,Not', 'SEDAN,Not'}): 0.13,
#  frozenset({'SUBURBAN,Going'}): 0.01,
#  frozenset({'Rail'}): 0.01,
#  frozenset({'Device'}): 0.02,
#  frozenset({'2012,10194609,PICKUP'}): 0.01,
#  frozenset({'SEDAN,Not', 'Straight'}): 0.25,
#  frozenset({'Entered,5NPDH4AE1CH'}): 0.01,
#  frozenset({'Entered,2009,NY,1,,HOND,HUMAN,Not'}): 0.01,
#  frozenset({'Entered,East,Not'}): 0.13,
#  frozenset({'Entered,2002,NY,1,,CHEV,HUMAN,Illness,HUMAN,Not'}): 0.01,
#  frozenset({'Type,Registration'}): 0.01,
#  frozenset({'Cylinders,Vehicle'}): 0.01,
#  frozenset({'2013,11603346,SUBURBAN,Not'}): 0.01,
#  frozenset({'2013,11231725,4'}): 0.01,
#  frozenset({'Vehicle'}): 0.01,
#  frozenset({'2013,11395783,TRACTOR,Not'}): 0.01,
#  frozenset({'Applicable,Not', 'SEDAN,Not'}): 0.31,
#  frozenset({'Entered,2001,NJ,1,,SUBA,HUMAN,Not'}): 0.01,
#  frozenset({'2013,11633945,4'}): 0.01,
#  frozenset({'Entered,Going', 'SEDAN,Not'}): 0.25,
#  frozenset({'Entered,South,None,2012,NY,1,0,AM/HA,HUMAN,Not'}): 0.01,
#  frozenset({'Closely,HUMAN,Not'}): 0.12,
#  frozenset({'/'}): 0.01,
#  frozenset({'Entered,East,Gas,2008,NY,1,10,FORD,HUMAN,Not'}): 0.01,
#  frozenset({'Non-Collision",'}): 0.01,
#  frozenset({'Usage'}): 0.02,
#  frozenset({'Entered,Going', 'Straight'}): 0.56,
#  frozenset({'Right'}): 0.05,
#  frozenset({'Entered,1988,UN,1,,GRUM,HUMAN,Not'}): 0.01,
#  frozenset({'(OMNIBUS),Not'}): 0.01,
#  frozenset({'2013,11202923,4'}): 0.01,
#  frozenset({'Applicable,"Tree,'}): 0.01,
#  frozenset({'-'}): 0.01,
#  frozenset({'End,'}): 0.01,
#  frozenset({'2013,10800352,4'}): 0.01,
#  frozenset({'Object",YV1RH592672'}): 0.01,
#  frozenset({'2013,11335010,MOTORCYCLE,MOTORCYCLE,Going'}): 0.01,
#  frozenset({'Entered,2012,NJ,1,,HYUN,HUMAN,Not'}): 0.01,
#  frozenset({'2013,11023684,4'}): 0.01,
#  frozenset({'Applicable,IU201417285'}): 0.01,
#  frozenset({'With",WA1CGAFE8CD'}): 0.01,
#  frozenset({'Involvement,HUMAN,Fell'}): 0.01,
#  frozenset({'Applicable,Not', 'Entered,Going', 'Straight'}): 0.36,
#  frozenset({'Non-Collision",1FTNX21S83E'}): 0.01,
#  frozenset({'Applicable,HUMAN,Not'}): 0.3,
#  frozenset({'Applicable,HUMAN,Not', 'Entered,Going'}): 0.1,
#  frozenset({'in'}): 0.05,
#  frozenset({'Entered,2010,NY,1,,CHEV,HUMAN,Failure'}): 0.01,
#  frozenset({'Ahead,Not', 'Entered,Going', 'Straight'}): 0.56,
#  frozenset({'Applicable,', 'Entered,Going'}): 0.23,
#  frozenset({'Applicable,1HD1JL5147Y'}): 0.01,
#  frozenset({'Entered,2010,NJ,1,,CHRY,HUMAN,Following'}): 0.01,
#  frozenset({'B'}): 0.01,
#  frozenset({'Applicable,4T1BB3EK4AU'}): 0.01,
#  frozenset({'Applicable,HUMAN,Not', 'Applicable,Not', 'Entered,Going'}): 0.1,
#  frozenset({'2013,11131133,POLICE'}): 0.01,
#  frozenset({'from'}): 0.01,
#  frozenset({'Entered,North,Not'}): 0.24,
#  frozenset({'2013,11783575,4'}): 0.01,
#  frozenset({'Entered,2011,MA,1,,CHEV,HUMAN,Not'}): 0.01,
#  frozenset({'Improper,"Overturned,'}): 0.01,
#  frozenset({'2013,11568750,PICKUP'}): 0.01,
#  frozenset({'2013,11094257,PICKUP'}): 0.01,
#  frozenset({'Ahead,Not', 'SEDAN,Not'}): 0.25,
#  frozenset({'or'}): 0.1,
#  frozenset({'Applicable,JH2AF60415K'}): 0.01,
#  frozenset({'2013,11115701,4'}): 0.01,
#  frozenset({'Applicable,', 'Applicable,HUMAN,Not'}): 0.11,
#  frozenset({'Entered,2004,PA,1,,PONT,HUMAN,Failure'}): 0.01,
#  frozenset({'2013,11462058,DELIVERY'}): 0.01,
#  frozenset({'SEDAN,Not'}): 0.44,
#  frozenset({"Entered,2012,NY,1,,FORD,ENVMT,Animal's"}): 0.01,
#  frozenset({'2013,11343055,PICKUP'}): 0.01,
#  frozenset({'Applicable,5NPET46C98H'}): 0.01,
#  frozenset({'Debris,HUMAN,Not'}): 0.02,
#  frozenset({'Left'}): 0.1,
#  frozenset({'Entered,2005,IN,1,,FRHT,HUMAN,Not'}): 0.01,
#  frozenset({'MOTORCYCLE,Making'}): 0.01,
#  frozenset({'2013,11245573,TRACTOR,Not'}): 0.01,
#  frozenset({'Entered,Going'}): 0.56,
#  frozenset({'Applicable,Not', 'Entered,Going'}): 0.36,
#  frozenset({'2013,11078782,4'}): 0.01,
#  frozenset({'2013,10920491,4'}): 0.01,
#  frozenset({'Slippery,"Earth'}): 0.01,
#  frozenset({'Entered,1997,CT,2,,FORD,HUMAN,Driver'}): 0.01,
#  frozenset({'Applicable,HUMAN,Not', 'Applicable,Not', 'SEDAN,Not'}): 0.13,
#  frozenset({'2013,11169688,4'}): 0.01,
#  frozenset({'2013,11053659,2'}): 0.01,
#  frozenset({'Entered,,,1,,,HUMAN,Pedestrian/Bicyclist'}): 0.01,
#  frozenset({'Entered,2013,NY,1,,HOND,HUMAN,Backing'}): 0.01,
#  frozenset({'of'}): 0.01,
#  frozenset({'2013,11095421,4'}): 0.01,
#  frozenset({'Keep'}): 0.01,
#  frozenset({'Description,Event'}): 0.01,
#  frozenset({'Changing,HUMAN,Driver'}): 0.01,
#  frozenset({'Object",4V4NC9EJXBN'}): 0.01,
#  frozenset({'Driving/Road'}): 0.01,
#  frozenset({'2013,11172280,4'}): 0.01,
#  frozenset({'Action,Not'}): 0.01,
#  frozenset({'Applicable,HUMAN,Not', 'Applicable,Not'}): 0.3,
#  frozenset({'Ahead,Not', 'Applicable,'}): 0.25,
#  frozenset({'Entered,2007,IA,1,,FRHT,HUMAN,Traffic'}): 0.01,
#  frozenset({'Applicable,1FUJBBAV27L'}): 0.01,
#  frozenset({'Applicable,KM8SC73D82U'}): 0.01,
#  frozenset({'Ahead,Not', 'Straight'}): 0.63,
#  frozenset({'Entered,Northeast,Gas,2005,NY,1,1,HONDA,HUMAN,Not'}): 0.01,
#  frozenset({'Cut/Ditch,'}): 0.02,
#  frozenset({'Entered,2000,NC,2,,FORD,HUMAN,Not'}): 0.01,
#  frozenset({'Entered,1997,NY,1,,TOYT,HUMAN,Driver'}): 0.01,
#  frozenset({'Speed,ENVMT,Pavement'}): 0.05,
#  frozenset({'Entered,5N6200F20C1'}): 0.01,
#  frozenset({'Ahead,Not', 'Applicable,Not'}): 0.39}

# %%
rules= generateRules(L,suppData, minConf=0.7)
# Out:
# (frozenset(['Entered,Going']), '-->', frozenset(['Ahead,Not']), 'conf:', 1.0)
# (frozenset(['Ahead,Not']), '-->', frozenset(['Entered,Going']), 'conf:', 0.888888888888889)
# (frozenset(['DOOR']), '-->', frozenset(['Applicable,Not']), 'conf:', 0.7021276595744682)
# (frozenset(['SEDAN,Not']), '-->', frozenset(['Applicable,Not']), 'conf:', 0.7045454545454546)
# (frozenset(['Applicable,']), '-->', frozenset(['Applicable,Not']), 'conf:', 0.7777777777777777)
# (frozenset(['DOOR']), '-->', frozenset(['SEDAN,Not']), 'conf:', 0.9361702127659575)
# (frozenset(['SEDAN,Not']), '-->', frozenset(['DOOR']), 'conf:', 1.0)
# (frozenset(['Straight']), '-->', frozenset(['Ahead,Not']), 'conf:', 1.0)
# (frozenset(['Ahead,Not']), '-->', frozenset(['Straight']), 'conf:', 1.0)
# (frozenset(['Applicable,HUMAN,Not']), '-->', frozenset(['Applicable,Not']), 'conf:', 1.0)
# (frozenset(['Entered,Going']), '-->', frozenset(['Straight']), 'conf:', 1.0)
# (frozenset(['Straight']), '-->', frozenset(['Entered,Going']), 'conf:', 0.888888888888889)
# (frozenset(['SEDAN,Not']), '-->', frozenset(['Applicable,Not', 'DOOR']), 'conf:', 0.7045454545454546)
# (frozenset(['Entered,Going']), '-->', frozenset(['Ahead,Not', 'Straight']), 'conf:', 1.0)
# (frozenset(['Straight']), '-->', frozenset(['Ahead,Not', 'Entered,Going']), 'conf:', 0.888888888888889)
# (frozenset(['Ahead,Not']), '-->', frozenset(['Straight', 'Entered,Going']), 'conf:', 0.888888888888889)
# (frozenset(['Applicable,Not', 'Straight']), '-->', frozenset(['Ahead,Not', 'Entered,Going']), 'conf:', 0.923076923076923)
# (frozenset(['Ahead,Not', 'Applicable,Not']), '-->', frozenset(['Straight', 'Entered,Going']), 'conf:', 0.923076923076923)
# (frozenset(['Applicable,Not', 'Entered,Going']), '-->', frozenset(['Ahead,Not', 'Straight']), 'conf:', 1.0)

# %%
# Copied from https://github.com/asaini/Apriori/blob/master/apriori.py

# %%
# %%writefile apriori_prg.py
# Copied from https://github.com/asaini/Apriori/blob/master/apriori.py
import sys
from itertools import chain, combinations
from collections import defaultdict
from optparse import OptionParser


def subsets(arr):
    """ Returns non empty subsets of arr"""
    return chain(*[combinations(arr, i + 1) for i, a in enumerate(arr)])


def returnItemsWithMinSupport(itemSet, transactionList, minSupport, freqSet):
        """calculates the support for items in the itemSet and returns a subset
       of the itemSet each of whose elements satisfies the minimum support"""
        _itemSet = set()
        localSet = defaultdict(int)

        for item in itemSet:
                for transaction in transactionList:
                        if item.issubset(transaction):
                                freqSet[item] += 1
                                localSet[item] += 1

        for item, count in localSet.items():
                support = float(count)/len(transactionList)

                if support >= minSupport:
                        _itemSet.add(item)

        return _itemSet


def joinSet(itemSet, length):
        """Join a set with itself and returns the n-element itemsets"""
        return set([i.union(j) for i in itemSet for j in itemSet if len(i.union(j)) == length])


def getItemSetTransactionList(data_iterator):
    transactionList = list()
    itemSet = set()
    for record in data_iterator:
        transaction = frozenset(record)
        transactionList.append(transaction)
        for item in transaction:
            itemSet.add(frozenset([item]))              # Generate 1-itemSets
    return itemSet, transactionList


def runApriori(data_iter, minSupport, minConfidence):
    """
    run the apriori algorithm. data_iter is a record iterator
    Return both:
     - items (tuple, support)
     - rules ((pretuple, posttuple), confidence)
    """
    itemSet, transactionList = getItemSetTransactionList(data_iter)

    freqSet = defaultdict(int)
    largeSet = dict()
    # Global dictionary which stores (key=n-itemSets,value=support)
    # which satisfy minSupport

    assocRules = dict()
    # Dictionary which stores Association Rules

    oneCSet = returnItemsWithMinSupport(itemSet,
                                        transactionList,
                                        minSupport,
                                        freqSet)

    currentLSet = oneCSet
    k = 2
    while(currentLSet != set([])):
        largeSet[k-1] = currentLSet
        currentLSet = joinSet(currentLSet, k)
        currentCSet = returnItemsWithMinSupport(currentLSet,
                                                transactionList,
                                                minSupport,
                                                freqSet)
        currentLSet = currentCSet
        k = k + 1

    def getSupport(item):
            """local function which Returns the support of an item"""
            return float(freqSet[item])/len(transactionList)

    toRetItems = []
    for key, value in largeSet.items():
        toRetItems.extend([(tuple(item), getSupport(item))
                           for item in value])

    toRetRules = []
    for key, value in largeSet.items()[1:]:
        for item in value:
            _subsets = map(frozenset, [x for x in subsets(item)])
            for element in _subsets:
                remain = item.difference(element)
                if len(remain) > 0:
                    confidence = getSupport(item)/getSupport(element)
                    if confidence >= minConfidence:
                        toRetRules.append(((tuple(element), tuple(remain)),
                                           confidence))
    return toRetItems, toRetRules


def printResults(items, rules):
    """prints the generated itemsets sorted by support and the confidence rules sorted by confidence"""
    for item, support in sorted(items, key=lambda (item, support): support):
        print "item: %s , %.3f" % (str(item), support)
    print "\n------------------------ RULES:"
    for rule, confidence in sorted(rules, key=lambda (rule, confidence): confidence):
        pre, post = rule
        print "Rule: %s ==> %s , %.3f" % (str(pre), str(post), confidence)


def dataFromFile(fname):
        """Function which reads from the file and yields a generator"""
        file_iter = open(fname, 'rU')
        for line in file_iter:
                line = line.strip().rstrip(',')                         # Remove trailing comma
                record = frozenset(line.split(','))
                yield record


if __name__ == "__main__":

    optparser = OptionParser()
    optparser.add_option('-f', '--inputFile',
                         dest='input',
                         help='filename containing csv',
                         default=None)
    optparser.add_option('-s', '--minSupport',
                         dest='minS',
                         help='minimum support value',
                         default=0.15,
                         type='float')
    optparser.add_option('-c', '--minConfidence',
                         dest='minC',
                         help='minimum confidence value',
                         default=0.6,
                         type='float')

    (options, args) = optparser.parse_args()

    inFile = None
    if options.input is None:
            inFile = sys.stdin
    elif options.input is not None:
            inFile = dataFromFile(options.input)
    else:
            print 'No dataset filename specified, system with exit\n'
            sys.exit('System will exit')

    minSupport = options.minS
    minConfidence = options.minC

    items, rules = runApriori(inFile, minSupport, minConfidence)

printResults(items, rules)
# Out:
# Writing apriori_prg.py

# %%
# %%cmd
# python apriori_prg.py -f Trafficdata.csv
# Out:
# Microsoft Windows [Version 10.0.15063]
# (c) 2017 Microsoft Corporation. All rights reserved.
#
# C:\Users\Vishnu\Documents\GitHub\big-data-python-class\Homeworks\Homework7>python apriori_prg.py -f Trafficdata.csv
# item: ('SUBURBAN',) , 0.150
# item: ('NJ',) , 0.150
# item: ('NY', '4 DOOR SEDAN') , 0.150
# item: ('East', 'Going Straight Ahead') , 0.150
# item: ('', 'SUBURBAN') , 0.150
# item: ('NJ', 'HUMAN') , 0.150
# item: ('SUBURBAN', 'HUMAN') , 0.150
# item: ('Not Applicable', 'Following Too Closely') , 0.150
# item: ('Going Straight Ahead', 'Following Too Closely') , 0.150
# item: ('North', 'Going Straight Ahead') , 0.150
# item: ('', 'NJ') , 0.150
# item: ('SUBURBAN', '2013') , 0.150
# item: ('Not Entered', 'NJ') , 0.150
# item: ('1', 'West') , 0.150
# item: ('East', '2013') , 0.150
# item: ('SUBURBAN', 'Not Applicable') , 0.150
# item: ('NJ', '2013') , 0.150
# item: ('Not Entered', 'SUBURBAN') , 0.150
# item: ('', 'SUBURBAN', 'HUMAN') , 0.150
# item: ('Not Entered', 'SUBURBAN', 'Not Applicable') , 0.150
# item: ('Not Entered', 'NJ', '2013') , 0.150
# item: ('Not Applicable', '2013', 'FORD') , 0.150
# item: ('', 'SUBURBAN', 'Not Applicable') , 0.150
# item: ('Not Entered', 'SUBURBAN', '2013') , 0.150
# item: ('SUBURBAN', 'Not Applicable', '2013') , 0.150
# item: ('Not Applicable', 'HUMAN', 'Following Too Closely') , 0.150
# item: ('SUBURBAN', 'Not Applicable', 'HUMAN') , 0.150
# item: ('NJ', '2013', 'HUMAN') , 0.150
# item: ('North', '2013', 'Going Straight Ahead') , 0.150
# item: ('SUBURBAN', '2013', 'HUMAN') , 0.150
# item: ('Following Too Closely', 'HUMAN', 'Going Straight Ahead') , 0.150
# item: ('', 'West', '1') , 0.150
# item: ('1', 'NY', '') , 0.150
# item: ('', 'Not Entered', 'SUBURBAN') , 0.150
# item: ('', 'NJ', 'HUMAN') , 0.150
# item: ('Not Entered', 'Going Straight Ahead', 'Following Too Closely') , 0.150
# item: ('NY', '4 DOOR SEDAN', 'Not Entered') , 0.150
# item: ('', '1', 'South') , 0.150
# item: ('East', '2013', 'HUMAN') , 0.150
# item: ('', 'North', 'Going Straight Ahead') , 0.150
# item: ('1', 'ENVMT', 'Going Straight Ahead') , 0.150
# item: ('', 'ENVMT', 'Going Straight Ahead') , 0.150
# item: ('Not Entered', 'Not Applicable', 'Following Too Closely') , 0.150
# item: ('North', 'HUMAN', 'Going Straight Ahead') , 0.150
# item: ('East', 'Not Applicable', 'Going Straight Ahead') , 0.150
# item: ('Not Entered', 'East', 'Going Straight Ahead') , 0.150
# item: ('NY', '4 DOOR SEDAN', 'HUMAN') , 0.150
# item: ('1', 'Not Entered', 'West') , 0.150
# item: ('', 'NJ', '2013') , 0.150
# item: ('Not Entered', 'SUBURBAN', 'HUMAN') , 0.150
# item: ('Not Entered', 'North', 'Going Straight Ahead') , 0.150
# item: ('Not Entered', 'NJ', 'HUMAN') , 0.150
# item: ('1', '2013', 'ENVMT') , 0.150
# item: ('', 'Not Entered', 'NJ') , 0.150
# item: ('1', 'West', '2013') , 0.150
# item: ('NY', '2013', 'Going Straight Ahead') , 0.150
# item: ('', 'SUBURBAN', '2013') , 0.150
# item: ('1', 'HUMAN', 'ENVMT') , 0.150
# item: ('Not Entered', 'East', '2013') , 0.150
# item: ('East', 'Not Applicable', '2013') , 0.150
# item: ('East', 'HUMAN', 'Going Straight Ahead') , 0.150
# item: ('HUMAN', 'SUBURBAN', 'Not Applicable', '2013') , 0.150
# item: ('', 'Not Entered', 'SUBURBAN', '2013') , 0.150
# item: ('1', 'West', 'Not Entered', '2013') , 0.150
# item: ('', 'ENVMT', '2013', 'Going Straight Ahead') , 0.150
# item: ('NJ', 'HUMAN', 'Not Entered', '2013') , 0.150
# item: ('HUMAN', 'ENVMT', '2013', 'Going Straight Ahead') , 0.150
# item: ('Not Entered', 'SUBURBAN', 'Not Applicable', '2013') , 0.150
# item: ('', 'HUMAN', 'SUBURBAN', 'Not Applicable') , 0.150
# item: ('', 'NJ', 'HUMAN', '2013') , 0.150
# item: ('HUMAN', 'Not Entered', 'SUBURBAN', '2013') , 0.150
# item: ('1', 'ENVMT', 'Not Entered', '2013') , 0.150
# item: ('', 'HUMAN', 'Not Entered', 'SUBURBAN') , 0.150
# item: ('', 'North', '2013', 'Going Straight Ahead') , 0.150
# item: ('NY', 'Not Entered', '2013', 'Going Straight Ahead') , 0.150
# item: ('HUMAN', 'East', 'Not Applicable', 'Going Straight Ahead') , 0.150
# item: ('', '1', 'Not Entered', 'South') , 0.150
# item: ('HUMAN', 'Following Too Closely', 'Not Entered', 'Going Straight Ahead') , 0.150
# item: ('HUMAN', 'Not Applicable', '2013', 'FORD') , 0.150
# item: ('1', 'NY', '', '2013') , 0.150
# item: ('', 'SUBURBAN', 'Not Applicable', '2013') , 0.150
# item: ('NY', 'HUMAN', '2013', 'Going Straight Ahead') , 0.150
# item: ('NY', '4 DOOR SEDAN', 'HUMAN', 'Not Entered') , 0.150
# item: ('', '1', 'HUMAN', 'South') , 0.150
# item: ('1', '', 'West', '2013') , 0.150
# item: ('North', 'HUMAN', '2013', 'Going Straight Ahead') , 0.150
# item: ('Not Entered', 'Not Applicable', '2013', 'FORD') , 0.150
# item: ('', 'HUMAN', 'SUBURBAN', '2013') , 0.150
# item: ('HUMAN', 'Following Too Closely', 'Not Entered', 'Not Applicable') , 0.150
# item: ('', 'NJ', 'HUMAN', 'Not Entered') , 0.150
# item: ('HUMAN', 'Not Entered', 'East', 'Going Straight Ahead') , 0.150
# item: ('', '1', 'HUMAN', 'NY') , 0.150
# item: ('1', 'ENVMT', 'Not Entered', 'Going Straight Ahead') , 0.150
# item: ('North', 'Not Entered', '2013', 'Going Straight Ahead') , 0.150
# item: ('1', 'HUMAN', 'ENVMT', 'Not Entered') , 0.150
# item: ('North', 'HUMAN', 'Not Entered', 'Going Straight Ahead') , 0.150
# item: ('', 'ENVMT', 'Not Entered', 'Going Straight Ahead') , 0.150
# item: ('Not Entered', 'East', 'Not Applicable', '2013') , 0.150
# item: ('Not Entered', 'East', 'Not Applicable', 'Going Straight Ahead') , 0.150
# item: ('', '1', 'Not Entered', 'West') , 0.150
# item: ('', 'North', 'Not Entered', 'Going Straight Ahead') , 0.150
# item: ('', 'Not Entered', 'SUBURBAN', 'Not Applicable') , 0.150
# item: ('1', 'NY', '', 'Not Entered') , 0.150
# item: ('', 'NJ', 'Not Entered', '2013') , 0.150
# item: ('HUMAN', 'Not Entered', 'SUBURBAN', 'Not Applicable') , 0.150
# item: ('HUMAN', 'Not Entered', 'East', '2013') , 0.150
# item: ('', '1', '2013', 'South') , 0.150
# item: ('', 'North', 'HUMAN', 'Going Straight Ahead') , 0.150
# item: ('HUMAN', 'East', 'Not Applicable', '2013') , 0.150
# item: ('', 'North', 'Not Entered', 'HUMAN', 'Going Straight Ahead') , 0.150
# item: ('', 'NJ', 'Not Entered', 'HUMAN', '2013') , 0.150
# item: ('Not Entered', 'SUBURBAN', 'HUMAN', 'Not Applicable', '2013') , 0.150
# item: ('Not Entered', 'HUMAN', 'East', 'Not Applicable', 'Going Straight Ahead') , 0.150
# item: ('ENVMT', 'Not Entered', 'HUMAN', '2013', 'Going Straight Ahead') , 0.150
# item: ('', '1', 'South', 'HUMAN', '2013') , 0.150
# item: ('', 'Not Entered', 'SUBURBAN', 'Not Applicable', '2013') , 0.150
# item: ('', 'Not Entered', '1', 'NY', 'HUMAN') , 0.150
# item: ('Not Entered', 'HUMAN', 'East', 'Not Applicable', '2013') , 0.150
# item: ('North', 'Not Entered', 'HUMAN', '2013', 'Going Straight Ahead') , 0.150
# item: ('', 'ENVMT', 'Not Entered', '2013', 'Going Straight Ahead') , 0.150
# item: ('', 'West', '1', 'Not Entered', '2013') , 0.150
# item: ('', 'Not Entered', '1', 'NY', '2013') , 0.150
# item: ('Not Entered', 'NY', 'HUMAN', '2013', 'Going Straight Ahead') , 0.150
# item: ('', 'Not Entered', 'SUBURBAN', 'HUMAN', 'Not Applicable') , 0.150
# item: ('Not Entered', 'FORD', 'HUMAN', 'Not Applicable', '2013') , 0.150
# item: ('', 'Not Entered', '1', '2013', 'South') , 0.150
# item: ('', 'SUBURBAN', 'HUMAN', 'Not Applicable', '2013') , 0.150
# item: ('', 'North', 'HUMAN', '2013', 'Going Straight Ahead') , 0.150
# item: ('', 'Not Entered', 'SUBURBAN', 'HUMAN', '2013') , 0.150
# item: ('', 'North', 'Not Entered', '2013', 'Going Straight Ahead') , 0.150
# item: ('', '1', 'NY', 'HUMAN', '2013') , 0.150
# item: ('', 'Not Entered', '1', 'HUMAN', 'South') , 0.150
# item: ('', 'Not Entered', '1', 'South', 'HUMAN', '2013') , 0.150
# item: ('', 'Not Entered', 'SUBURBAN', 'HUMAN', 'Not Applicable', '2013') , 0.150
# item: ('', 'Not Entered', '1', 'NY', 'HUMAN', '2013') , 0.150
# item: ('', 'North', 'Not Entered', 'HUMAN', '2013', 'Going Straight Ahead') , 0.150
# item: ('Following Too Closely',) , 0.160
# item: ('Not Entered', 'Following Too Closely') , 0.160
# item: ('2013', 'FORD') , 0.160
# item: ('West', 'Not Applicable') , 0.160
# item: ('1', 'East') , 0.160
# item: ('1', 'ENVMT') , 0.160
# item: ('HUMAN', 'Following Too Closely') , 0.160
# item: ('ENVMT', 'HUMAN', 'Going Straight Ahead') , 0.160
# item: ('Going Straight Ahead', '2013', 'ENVMT') , 0.160
# item: ('1', 'East', 'HUMAN') , 0.160
# item: ('HUMAN', '2013', 'FORD') , 0.160
# item: ('Not Entered', 'Not Applicable', 'West') , 0.160
# item: ('Not Entered', '2013', 'FORD') , 0.160
# item: ('1', 'Not Entered', 'ENVMT') , 0.160
# item: ('Not Entered', 'HUMAN', 'Following Too Closely') , 0.160
# item: ('1', 'South', '2013') , 0.160
# item: ('1', 'Not Entered', 'East') , 0.160
# item: ('1', 'East', 'Not Applicable') , 0.160
# item: ('', 'HUMAN', 'ENVMT') , 0.160
# item: ('1', 'NY', 'Going Straight Ahead') , 0.160
# item: ('NY', 'Not Applicable', 'Going Straight Ahead') , 0.160
# item: ('West', 'Not Applicable', 'HUMAN') , 0.160
# item: ('West', 'Not Applicable', '2013') , 0.160
# item: ('', 'West', 'Not Applicable') , 0.160
# item: ('1', 'NY', 'HUMAN', 'Going Straight Ahead') , 0.160
# item: ('HUMAN', 'ENVMT', 'Not Entered', 'Going Straight Ahead') , 0.160
# item: ('HUMAN', 'Not Entered', '2013', 'FORD') , 0.160
# item: ('ENVMT', 'Not Entered', '2013', 'Going Straight Ahead') , 0.160
# item: ('', 'HUMAN', 'West', 'Not Applicable') , 0.160
# item: ('1', 'South', 'HUMAN', '2013') , 0.160
# item: ('1', 'NY', 'Not Entered', 'Going Straight Ahead') , 0.160
# item: ('', 'West', 'Not Applicable', '2013') , 0.160
# item: ('', 'HUMAN', 'ENVMT', 'Not Entered') , 0.160
# item: ('1', 'NY', 'Not Applicable', '2013') , 0.160
# item: ('1', 'HUMAN', 'East', 'Not Applicable') , 0.160
# item: ('1', 'HUMAN', 'Not Entered', 'East') , 0.160
# item: ('1', 'South', 'Not Entered', '2013') , 0.160
# item: ('1', 'Not Entered', 'East', 'Not Applicable') , 0.160
# item: ('', 'HUMAN', 'ENVMT', '2013') , 0.160
# item: ('', 'West', 'Not Entered', 'Not Applicable') , 0.160
# item: ('NY', 'Not Entered', 'Not Applicable', 'Going Straight Ahead') , 0.160
# item: ('HUMAN', 'West', 'Not Applicable', '2013') , 0.160
# item: ('HUMAN', 'West', 'Not Entered', 'Not Applicable') , 0.160
# item: ('NY', 'HUMAN', 'Not Applicable', 'Going Straight Ahead') , 0.160
# item: ('West', 'Not Entered', 'Not Applicable', '2013') , 0.160
# item: ('Not Entered', '1', 'HUMAN', 'East', 'Not Applicable') , 0.160
# item: ('Not Entered', '1', 'South', 'HUMAN', '2013') , 0.160
# item: ('', 'West', 'HUMAN', 'Not Entered', 'Not Applicable') , 0.160
# item: ('Not Entered', 'NY', 'HUMAN', 'Not Applicable', 'Going Straight Ahead') , 0.160
# item: ('1', 'NY', 'HUMAN', 'Not Applicable', '2013') , 0.160
# item: ('', 'ENVMT', 'Not Entered', 'HUMAN', '2013') , 0.160
# item: ('Not Entered', '1', 'NY', 'Not Applicable', '2013') , 0.160
# item: ('Not Entered', 'HUMAN', 'West', 'Not Applicable', '2013') , 0.160
# item: ('', 'West', 'HUMAN', 'Not Applicable', '2013') , 0.160
# item: ('Not Entered', '1', 'NY', 'HUMAN', 'Going Straight Ahead') , 0.160
# item: ('', 'Not Entered', 'West', 'Not Applicable', '2013') , 0.160
# item: ('Not Entered', '1', 'NY', 'HUMAN', 'Not Applicable', '2013') , 0.160
# item: ('', 'Not Entered', 'HUMAN', 'West', 'Not Applicable', '2013') , 0.160
# item: ('2012',) , 0.170
# item: ('', 'ENVMT') , 0.170
# item: ('HUMAN', '2012') , 0.170
# item: ('South', 'Going Straight Ahead') , 0.170
# item: ('West', 'HUMAN') , 0.170
# item: ('Not Entered', '2012') , 0.170
# item: ('Going Straight Ahead', 'ENVMT') , 0.170
# item: ('Not Applicable', 'FORD') , 0.170
# item: ('', 'Not Entered', 'ENVMT') , 0.170
# item: ('HUMAN', 'South', 'Going Straight Ahead') , 0.170
# item: ('Not Entered', 'HUMAN', '2012') , 0.170
# item: ('Not Entered', 'HUMAN', 'West') , 0.170
# item: ('Not Applicable', 'HUMAN', 'FORD') , 0.170
# item: ('West', '2013', 'HUMAN') , 0.170
# item: ('', 'West', 'HUMAN') , 0.170
# item: ('Not Entered', 'South', 'Going Straight Ahead') , 0.170
# item: ('Not Entered', 'Not Applicable', 'FORD') , 0.170
# item: ('Not Entered', 'Going Straight Ahead', 'ENVMT') , 0.170
# item: ('HUMAN', '2013', 'ENVMT') , 0.170
# item: ('', '2013', 'ENVMT') , 0.170
# item: ('HUMAN', 'Not Entered', 'South', 'Going Straight Ahead') , 0.170
# item: ('', 'ENVMT', 'Not Entered', '2013') , 0.170
# item: ('HUMAN', 'Not Entered', 'Not Applicable', 'FORD') , 0.170
# item: ('HUMAN', 'ENVMT', 'Not Entered', '2013') , 0.170
# item: ('', 'HUMAN', 'West', 'Not Entered') , 0.170
# item: ('HUMAN', 'West', 'Not Entered', '2013') , 0.170
# item: ('', 'HUMAN', 'West', '2013') , 0.170
# item: ('', 'Not Entered', 'HUMAN', 'West', '2013') , 0.170
# item: ('FORD',) , 0.180
# item: ('East',) , 0.180
# item: ('West',) , 0.180
# item: ('2013', 'ENVMT') , 0.180
# item: ('', 'West') , 0.180
# item: ('Not Entered', 'West') , 0.180
# item: ('East', 'HUMAN') , 0.180
# item: ('East', 'Not Applicable') , 0.180
# item: ('Not Entered', 'East') , 0.180
# item: ('HUMAN', 'ENVMT') , 0.180
# item: ('West', '2013') , 0.180
# item: ('HUMAN', 'FORD') , 0.180
# item: ('Not Entered', 'FORD') , 0.180
# item: ('Not Entered', '2013', 'ENVMT') , 0.180
# item: ('1', 'NY', '2013') , 0.180
# item: ('', 'West', '2013') , 0.180
# item: ('1', 'North', 'Not Applicable') , 0.180
# item: ('East', 'Not Applicable', 'HUMAN') , 0.180
# item: ('Not Entered', 'HUMAN', 'FORD') , 0.180
# item: ('Not Entered', 'HUMAN', 'ENVMT') , 0.180
# item: ('Not Entered', '2013', 'West') , 0.180
# item: ('Not Entered', 'East', 'HUMAN') , 0.180
# item: ('Not Entered', 'East', 'Not Applicable') , 0.180
# item: ('', 'West', 'Not Entered') , 0.180
# item: ('HUMAN', 'Not Entered', 'East', 'Not Applicable') , 0.180
# item: ('1', 'North', 'HUMAN', 'Not Applicable') , 0.180
# item: ('1', 'North', 'Not Applicable', '2013') , 0.180
# item: ('1', 'NY', 'Not Entered', '2013') , 0.180
# item: ('1', 'North', 'Not Entered', 'Not Applicable') , 0.180
# item: ('1', '', 'North', 'Not Applicable') , 0.180
# item: ('', 'Not Entered', 'West', '2013') , 0.180
# item: ('1', 'NY', 'HUMAN', '2013') , 0.180
# item: ('', 'North', '1', 'Not Applicable', '2013') , 0.180
# item: ('4 DOOR SEDAN', '1', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.180
# item: ('Not Entered', '1', 'NY', 'HUMAN', '2013') , 0.180
# item: ('', '4 DOOR SEDAN', '1', 'Not Applicable', 'Going Straight Ahead') , 0.180
# item: ('North', 'Not Entered', '1', 'HUMAN', 'Not Applicable') , 0.180
# item: ('North', '1', 'HUMAN', 'Not Applicable', '2013') , 0.180
# item: ('', 'North', 'Not Entered', '1', 'Not Applicable') , 0.180
# item: ('', 'North', '1', 'HUMAN', 'Not Applicable') , 0.180
# item: ('North', 'Not Entered', '1', 'Not Applicable', '2013') , 0.180
# item: ('', '4 DOOR SEDAN', '1', 'HUMAN', 'Not Applicable', 'Going Straight Ahead') , 0.180
# item: ('', 'North', 'Not Entered', '1', 'Not Applicable', '2013') , 0.180
# item: ('', 'North', 'Not Entered', '1', 'HUMAN', 'Not Applicable') , 0.180
# item: ('', '4 DOOR SEDAN', 'Not Entered', '1', 'Not Applicable', 'Going Straight Ahead') , 0.180
# item: ('', '4 DOOR SEDAN', '1', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.180
# item: ('4 DOOR SEDAN', '1', 'HUMAN', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.180
# item: ('', 'North', '1', 'HUMAN', 'Not Applicable', '2013') , 0.180
# item: ('North', 'Not Entered', '1', 'HUMAN', 'Not Applicable', '2013') , 0.180
# item: ('4 DOOR SEDAN', 'Not Entered', '1', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.180
# item: ('', '4 DOOR SEDAN', 'Not Entered', '1', 'HUMAN', 'Not Applicable', 'Going Straight Ahead') , 0.180
# item: ('4 DOOR SEDAN', 'Not Entered', '1', 'HUMAN', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.180
# item: ('', 'North', 'Not Entered', '1', 'HUMAN', 'Not Applicable', '2013') , 0.180
# item: ('', '4 DOOR SEDAN', 'Not Entered', '1', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.180
# item: ('', '4 DOOR SEDAN', '1', 'HUMAN', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.180
# item: ('', '4 DOOR SEDAN', 'Not Entered', '1', 'HUMAN', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.180
# item: ('ENVMT',) , 0.190
# item: ('Not Entered', 'ENVMT') , 0.190
# item: ('1', 'South') , 0.190
# item: ('1', 'South', 'HUMAN') , 0.190
# item: ('', 'NY', 'Not Applicable') , 0.190
# item: ('1', 'Not Entered', 'South') , 0.190
# item: ('', 'NY', 'Not Entered', 'Not Applicable') , 0.190
# item: ('1', 'HUMAN', 'Not Entered', 'South') , 0.190
# item: ('', 'NY', 'HUMAN', 'Not Applicable') , 0.190
# item: ('', 'NY', 'Not Applicable', '2013') , 0.190
# item: ('', 'NY', 'HUMAN', 'Not Applicable', '2013') , 0.190
# item: ('', 'Not Entered', 'NY', 'Not Applicable', '2013') , 0.190
# item: ('', 'Not Entered', 'NY', 'HUMAN', 'Not Applicable') , 0.190
# item: ('', 'Not Entered', 'NY', 'HUMAN', 'Not Applicable', '2013') , 0.190
# item: ('NY', 'Going Straight Ahead') , 0.200
# item: ('1', 'North') , 0.200
# item: ('', 'NY') , 0.200
# item: ('', 'NY', 'HUMAN') , 0.200
# item: ('', 'NY', '2013') , 0.200
# item: ('1', 'North', 'HUMAN') , 0.200
# item: ('NY', 'Not Entered', 'Going Straight Ahead') , 0.200
# item: ('1', 'NY', 'Not Applicable') , 0.200
# item: ('', '1', 'North') , 0.200
# item: ('NY', 'HUMAN', 'Going Straight Ahead') , 0.200
# item: ('', 'Not Entered', 'NY') , 0.200
# item: ('1', 'North', '2013') , 0.200
# item: ('1', 'Not Entered', 'North') , 0.200
# item: ('1', '4 DOOR SEDAN', '2013', 'Going Straight Ahead') , 0.200
# item: ('1', 'North', 'HUMAN', 'Not Entered') , 0.200
# item: ('', 'NY', 'HUMAN', '2013') , 0.200
# item: ('1', 'North', 'HUMAN', '2013') , 0.200
# item: ('', '1', 'North', 'HUMAN') , 0.200
# item: ('', '1', 'North', 'Not Entered') , 0.200
# item: ('1', 'NY', 'Not Entered', 'Not Applicable') , 0.200
# item: ('NY', 'HUMAN', 'Not Entered', 'Going Straight Ahead') , 0.200
# item: ('1', '4 DOOR SEDAN', 'Not Applicable', 'Going Straight Ahead') , 0.200
# item: ('', '1', '4 DOOR SEDAN', 'Going Straight Ahead') , 0.200
# item: ('1', 'North', 'Not Entered', '2013') , 0.200
# item: ('1', '', 'North', '2013') , 0.200
# item: ('1', 'NY', 'HUMAN', 'Not Applicable') , 0.200
# item: ('', 'NY', 'HUMAN', 'Not Entered') , 0.200
# item: ('', 'NY', 'Not Entered', '2013') , 0.200
# item: ('4 DOOR SEDAN', '1', 'HUMAN', 'Not Applicable', 'Going Straight Ahead') , 0.200
# item: ('4 DOOR SEDAN', '1', 'HUMAN', '2013', 'Going Straight Ahead') , 0.200
# item: ('', '4 DOOR SEDAN', 'Not Entered', '1', 'Going Straight Ahead') , 0.200
# item: ('4 DOOR SEDAN', 'Not Entered', '1', '2013', 'Going Straight Ahead') , 0.200
# item: ('', '4 DOOR SEDAN', '1', '2013', 'Going Straight Ahead') , 0.200
# item: ('', '4 DOOR SEDAN', '1', 'HUMAN', 'Going Straight Ahead') , 0.200
# item: ('', 'North', 'Not Entered', '1', '2013') , 0.200
# item: ('', 'North', 'Not Entered', '1', 'HUMAN') , 0.200
# item: ('4 DOOR SEDAN', 'Not Entered', '1', 'Not Applicable', 'Going Straight Ahead') , 0.200
# item: ('North', 'Not Entered', '1', 'HUMAN', '2013') , 0.200
# item: ('Not Entered', '1', 'NY', 'HUMAN', 'Not Applicable') , 0.200
# item: ('', 'North', '1', 'HUMAN', '2013') , 0.200
# item: ('', 'Not Entered', 'NY', 'HUMAN', '2013') , 0.200
# item: ('', '4 DOOR SEDAN', '1', 'HUMAN', '2013', 'Going Straight Ahead') , 0.200
# item: ('', 'North', 'Not Entered', '1', 'HUMAN', '2013') , 0.200
# item: ('', '4 DOOR SEDAN', 'Not Entered', '1', '2013', 'Going Straight Ahead') , 0.200
# item: ('', '4 DOOR SEDAN', 'Not Entered', '1', 'HUMAN', 'Going Straight Ahead') , 0.200
# item: ('4 DOOR SEDAN', 'Not Entered', '1', 'HUMAN', '2013', 'Going Straight Ahead') , 0.200
# item: ('4 DOOR SEDAN', 'Not Entered', '1', 'HUMAN', 'Not Applicable', 'Going Straight Ahead') , 0.200
# item: ('', '4 DOOR SEDAN', 'Not Entered', '1', 'HUMAN', '2013', 'Going Straight Ahead') , 0.200
# item: ('NY', 'Not Applicable', '2013') , 0.210
# item: ('Not Applicable', 'South', '2013') , 0.210
# item: ('', 'Not Applicable', 'South') , 0.210
# item: ('NY', 'Not Entered', 'Not Applicable', '2013') , 0.210
# item: ('', 'Not Entered', 'Not Applicable', 'South') , 0.210
# item: ('', '4 DOOR SEDAN', 'Not Applicable', 'Going Straight Ahead') , 0.210
# item: ('4 DOOR SEDAN', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.210
# item: ('South', 'Not Entered', 'Not Applicable', '2013') , 0.210
# item: ('South', 'HUMAN', 'Not Applicable', '2013') , 0.210
# item: ('', 'South', 'Not Applicable', '2013') , 0.210
# item: ('NY', 'HUMAN', 'Not Applicable', '2013') , 0.210
# item: ('', 'HUMAN', 'Not Applicable', 'South') , 0.210
# item: ('', 'Not Entered', 'South', 'Not Applicable', '2013') , 0.210
# item: ('', '4 DOOR SEDAN', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.210
# item: ('4 DOOR SEDAN', 'HUMAN', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.210
# item: ('', 'South', 'HUMAN', 'Not Applicable', '2013') , 0.210
# item: ('Not Entered', '2013', 'HUMAN', 'Not Applicable', 'South') , 0.210
# item: ('4 DOOR SEDAN', 'Not Entered', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.210
# item: ('', '4 DOOR SEDAN', 'HUMAN', 'Not Applicable', 'Going Straight Ahead') , 0.210
# item: ('Not Entered', 'NY', 'HUMAN', 'Not Applicable', '2013') , 0.210
# item: ('', '4 DOOR SEDAN', 'Not Entered', 'Not Applicable', 'Going Straight Ahead') , 0.210
# item: ('', 'Not Entered', 'HUMAN', 'Not Applicable', 'South') , 0.210
# item: ('', '4 DOOR SEDAN', 'Not Entered', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.210
# item: ('', '4 DOOR SEDAN', 'Not Entered', 'HUMAN', 'Not Applicable', 'Going Straight Ahead') , 0.210
# item: ('', '4 DOOR SEDAN', 'HUMAN', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.210
# item: ('4 DOOR SEDAN', 'Not Entered', 'HUMAN', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.210
# item: ('', 'Not Entered', 'South', 'HUMAN', 'Not Applicable', '2013') , 0.210
# item: ('', '4 DOOR SEDAN', 'Not Entered', 'HUMAN', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.210
# item: ('Not Applicable', 'South') , 0.220
# item: ('North', 'Not Applicable') , 0.220
# item: ('', 'South') , 0.220
# item: ('Not Applicable', 'North', 'HUMAN') , 0.220
# item: ('', 'Not Entered', 'South') , 0.220
# item: ('', '2013', 'South') , 0.220
# item: ('Not Entered', 'Not Applicable', 'South') , 0.220
# item: ('', 'Not Applicable', 'North') , 0.220
# item: ('Not Applicable', 'HUMAN', 'South') , 0.220
# item: ('', 'HUMAN', 'South') , 0.220
# item: ('Not Entered', 'Not Applicable', 'North') , 0.220
# item: ('North', 'Not Applicable', '2013') , 0.220
# item: ('HUMAN', 'Not Entered', 'Not Applicable', 'South') , 0.220
# item: ('', 'North', 'Not Applicable', '2013') , 0.220
# item: ('North', 'HUMAN', 'Not Applicable', '2013') , 0.220
# item: ('North', 'HUMAN', 'Not Entered', 'Not Applicable') , 0.220
# item: ('', '2013', 'Not Entered', 'South') , 0.220
# item: ('', 'North', 'HUMAN', 'Not Applicable') , 0.220
# item: ('', 'North', 'Not Entered', 'Not Applicable') , 0.220
# item: ('', 'HUMAN', 'Not Entered', 'South') , 0.220
# item: ('North', 'Not Entered', 'Not Applicable', '2013') , 0.220
# item: ('', 'South', 'HUMAN', '2013') , 0.220
# item: ('', 'North', 'Not Entered', 'HUMAN', 'Not Applicable') , 0.220
# item: ('', 'North', 'Not Entered', 'Not Applicable', '2013') , 0.220
# item: ('North', 'Not Entered', 'HUMAN', 'Not Applicable', '2013') , 0.220
# item: ('', 'Not Entered', 'South', 'HUMAN', '2013') , 0.220
# item: ('', 'North', 'HUMAN', 'Not Applicable', '2013') , 0.220
# item: ('', 'North', 'Not Entered', 'HUMAN', 'Not Applicable', '2013') , 0.220
# item: ('NY', '2013') , 0.230
# item: ('South', '2013') , 0.230
# item: ('4 DOOR SEDAN', '2013', 'Going Straight Ahead') , 0.230
# item: ('', '4 DOOR SEDAN', 'Going Straight Ahead') , 0.230
# item: ('1', '4 DOOR SEDAN', 'Going Straight Ahead') , 0.230
# item: ('South', '2013', 'HUMAN') , 0.230
# item: ('NY', '2013', 'Not Entered') , 0.230
# item: ('Not Applicable', '4 DOOR SEDAN', 'Going Straight Ahead') , 0.230
# item: ('NY', 'HUMAN', '2013') , 0.230
# item: ('Not Entered', '2013', 'South') , 0.230
# item: ('1', '4 DOOR SEDAN', 'Not Entered', 'Going Straight Ahead') , 0.230
# item: ('4 DOOR SEDAN', 'HUMAN', '2013', 'Going Straight Ahead') , 0.230
# item: ('South', 'HUMAN', 'Not Entered', '2013') , 0.230
# item: ('NY', 'HUMAN', 'Not Entered', '2013') , 0.230
# item: ('', '4 DOOR SEDAN', 'HUMAN', 'Going Straight Ahead') , 0.230
# item: ('1', '4 DOOR SEDAN', 'HUMAN', 'Going Straight Ahead') , 0.230
# item: ('4 DOOR SEDAN', 'Not Entered', '2013', 'Going Straight Ahead') , 0.230
# item: ('', '4 DOOR SEDAN', '2013', 'Going Straight Ahead') , 0.230
# item: ('4 DOOR SEDAN', 'Not Entered', 'Not Applicable', 'Going Straight Ahead') , 0.230
# item: ('', '4 DOOR SEDAN', 'Not Entered', 'Going Straight Ahead') , 0.230
# item: ('4 DOOR SEDAN', 'HUMAN', 'Not Applicable', 'Going Straight Ahead') , 0.230
# item: ('', '4 DOOR SEDAN', 'Not Entered', '2013', 'Going Straight Ahead') , 0.230
# item: ('', '4 DOOR SEDAN', 'HUMAN', '2013', 'Going Straight Ahead') , 0.230
# item: ('4 DOOR SEDAN', 'Not Entered', 'HUMAN', 'Not Applicable', 'Going Straight Ahead') , 0.230
# item: ('4 DOOR SEDAN', 'Not Entered', '1', 'HUMAN', 'Going Straight Ahead') , 0.230
# item: ('', '4 DOOR SEDAN', 'Not Entered', 'HUMAN', 'Going Straight Ahead') , 0.230
# item: ('4 DOOR SEDAN', 'Not Entered', 'HUMAN', '2013', 'Going Straight Ahead') , 0.230
# item: ('', '4 DOOR SEDAN', 'Not Entered', 'HUMAN', '2013', 'Going Straight Ahead') , 0.230
# item: ('North',) , 0.240
# item: ('', 'North') , 0.240
# item: ('North', 'HUMAN') , 0.240
# item: ('Not Entered', 'North') , 0.240
# item: ('North', '2013') , 0.240
# item: ('', 'Not Entered', 'North') , 0.240
# item: ('Not Entered', 'North', 'HUMAN') , 0.240
# item: ('Not Entered', 'North', '2013') , 0.240
# item: ('', 'North', '2013') , 0.240
# item: ('North', '2013', 'HUMAN') , 0.240
# item: ('', 'North', 'HUMAN') , 0.240
# item: ('', 'North', 'Not Entered', '2013') , 0.240
# item: ('', 'North', 'HUMAN', 'Not Entered') , 0.240
# item: ('North', 'HUMAN', 'Not Entered', '2013') , 0.240
# item: ('', 'North', 'HUMAN', '2013') , 0.240
# item: ('', 'North', 'Not Entered', 'HUMAN', '2013') , 0.240
# item: ('1', 'NY') , 0.250
# item: ('1', 'Not Entered', 'NY') , 0.250
# item: ('1', 'NY', 'HUMAN') , 0.250
# item: ('1', 'NY', 'HUMAN', 'Not Entered') , 0.250
# item: ('4 DOOR SEDAN', 'Going Straight Ahead') , 0.260
# item: ('Not Entered', '4 DOOR SEDAN', 'Going Straight Ahead') , 0.260
# item: ('4 DOOR SEDAN', 'HUMAN', 'Going Straight Ahead') , 0.260
# item: ('4 DOOR SEDAN', 'HUMAN', 'Not Entered', 'Going Straight Ahead') , 0.260
# item: ('South',) , 0.270
# item: ('Not Entered', 'South') , 0.270
# item: ('NY', 'Not Applicable') , 0.270
# item: ('South', 'HUMAN') , 0.270
# item: ('Not Entered', 'Not Applicable', 'NY') , 0.270
# item: ('Not Entered', 'HUMAN', 'South') , 0.270
# item: ('NY', 'Not Applicable', 'HUMAN') , 0.270
# item: ('1', '4 DOOR SEDAN', 'Not Applicable', '2013') , 0.270
# item: ('NY', 'HUMAN', 'Not Entered', 'Not Applicable') , 0.270
# item: ('1', '', '4 DOOR SEDAN', 'Not Applicable') , 0.270
# item: ('', '4 DOOR SEDAN', 'Not Entered', '1', 'Not Applicable') , 0.270
# item: ('4 DOOR SEDAN', 'Not Entered', '1', 'Not Applicable', '2013') , 0.270
# item: ('4 DOOR SEDAN', '1', 'HUMAN', 'Not Applicable', '2013') , 0.270
# item: ('', '4 DOOR SEDAN', '1', 'Not Applicable', '2013') , 0.270
# item: ('', '4 DOOR SEDAN', '1', 'HUMAN', 'Not Applicable') , 0.270
# item: ('', '4 DOOR SEDAN', '1', 'HUMAN', 'Not Applicable', '2013') , 0.270
# item: ('4 DOOR SEDAN', 'Not Entered', '1', 'HUMAN', 'Not Applicable', '2013') , 0.270
# item: ('', '4 DOOR SEDAN', 'Not Entered', '1', 'HUMAN', 'Not Applicable') , 0.270
# item: ('', '4 DOOR SEDAN', 'Not Entered', '1', 'Not Applicable', '2013') , 0.270
# item: ('', '4 DOOR SEDAN', 'Not Entered', '1', 'HUMAN', 'Not Applicable', '2013') , 0.270
# item: ('1', 'Not Applicable', '4 DOOR SEDAN') , 0.290
# item: ('1', '4 DOOR SEDAN', 'HUMAN', 'Not Applicable') , 0.290
# item: ('1', '4 DOOR SEDAN', 'Not Entered', 'Not Applicable') , 0.290
# item: ('4 DOOR SEDAN', 'Not Entered', '1', 'HUMAN', 'Not Applicable') , 0.290
# item: ('1', '', '4 DOOR SEDAN') , 0.300
# item: ('1', '4 DOOR SEDAN', '2013') , 0.300
# item: ('1', '', '4 DOOR SEDAN', 'Not Entered') , 0.300
# item: ('1', '', '4 DOOR SEDAN', '2013') , 0.300
# item: ('1', '4 DOOR SEDAN', 'HUMAN', '2013') , 0.300
# item: ('', '1', '4 DOOR SEDAN', 'HUMAN') , 0.300
# item: ('1', '4 DOOR SEDAN', 'Not Entered', '2013') , 0.300
# item: ('', '4 DOOR SEDAN', 'Not Entered', '1', 'HUMAN') , 0.300
# item: ('', '4 DOOR SEDAN', '1', 'HUMAN', '2013') , 0.300
# item: ('4 DOOR SEDAN', 'Not Entered', '1', 'HUMAN', '2013') , 0.300
# item: ('', '4 DOOR SEDAN', 'Not Entered', '1', '2013') , 0.300
# item: ('', '4 DOOR SEDAN', 'Not Entered', '1', 'HUMAN', '2013') , 0.300
# item: ('NY',) , 0.320
# item: ('NY', 'Not Entered') , 0.320
# item: ('NY', 'HUMAN') , 0.320
# item: ('Not Entered', 'HUMAN', 'NY') , 0.320
# item: ('1', '4 DOOR SEDAN') , 0.330
# item: ('1', 'Not Entered', '4 DOOR SEDAN') , 0.330
# item: ('1', '4 DOOR SEDAN', 'HUMAN') , 0.330
# item: ('1', '4 DOOR SEDAN', 'HUMAN', 'Not Entered') , 0.330
# item: ('', 'Not Applicable', '4 DOOR SEDAN') , 0.370
# item: ('Not Applicable', '4 DOOR SEDAN', '2013') , 0.370
# item: ('', '4 DOOR SEDAN', 'Not Applicable', '2013') , 0.370
# item: ('', '4 DOOR SEDAN', 'HUMAN', 'Not Applicable') , 0.370
# item: ('4 DOOR SEDAN', 'Not Entered', 'Not Applicable', '2013') , 0.370
# item: ('', '4 DOOR SEDAN', 'Not Entered', 'Not Applicable') , 0.370
# item: ('4 DOOR SEDAN', 'HUMAN', 'Not Applicable', '2013') , 0.370
# item: ('', '4 DOOR SEDAN', 'Not Entered', 'HUMAN', 'Not Applicable') , 0.370
# item: ('', '4 DOOR SEDAN', 'Not Entered', 'Not Applicable', '2013') , 0.370
# item: ('', '4 DOOR SEDAN', 'HUMAN', 'Not Applicable', '2013') , 0.370
# item: ('4 DOOR SEDAN', 'Not Entered', 'HUMAN', 'Not Applicable', '2013') , 0.370
# item: ('', '4 DOOR SEDAN', 'Not Entered', 'HUMAN', 'Not Applicable', '2013') , 0.370
# item: ('Not Applicable', '4 DOOR SEDAN') , 0.390
# item: ('Not Applicable', '4 DOOR SEDAN', 'HUMAN') , 0.390
# item: ('Not Entered', 'Not Applicable', '4 DOOR SEDAN') , 0.390
# item: ('4 DOOR SEDAN', 'HUMAN', 'Not Entered', 'Not Applicable') , 0.390
# item: ('4 DOOR SEDAN', '2013') , 0.400
# item: ('', '4 DOOR SEDAN') , 0.400
# item: ('Not Entered', '4 DOOR SEDAN', '2013') , 0.400
# item: ('', '4 DOOR SEDAN', 'HUMAN') , 0.400
# item: ('', 'Not Entered', '4 DOOR SEDAN') , 0.400
# item: ('2013', '4 DOOR SEDAN', 'HUMAN') , 0.400
# item: ('', '4 DOOR SEDAN', '2013') , 0.400
# item: ('', '4 DOOR SEDAN', 'HUMAN', 'Not Entered') , 0.400
# item: ('4 DOOR SEDAN', 'HUMAN', 'Not Entered', '2013') , 0.400
# item: ('', '4 DOOR SEDAN', 'HUMAN', '2013') , 0.400
# item: ('', '4 DOOR SEDAN', 'Not Entered', '2013') , 0.400
# item: ('', '4 DOOR SEDAN', 'Not Entered', 'HUMAN', '2013') , 0.400
# item: ('4 DOOR SEDAN',) , 0.430
# item: ('4 DOOR SEDAN', 'HUMAN') , 0.430
# item: ('Not Entered', '4 DOOR SEDAN') , 0.430
# item: ('Not Entered', '4 DOOR SEDAN', 'HUMAN') , 0.430
# item: ('1', '', 'Not Applicable', 'Going Straight Ahead') , 0.440
# item: ('', '1', 'HUMAN', 'Not Applicable', 'Going Straight Ahead') , 0.440
# item: ('', 'Not Entered', '1', 'Not Applicable', 'Going Straight Ahead') , 0.440
# item: ('', '1', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.440
# item: ('', 'Not Entered', '1', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.440
# item: ('', '1', 'HUMAN', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.440
# item: ('', 'Not Entered', '1', 'HUMAN', 'Not Applicable', 'Going Straight Ahead') , 0.440
# item: ('', 'Not Entered', '1', 'HUMAN', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.440
# item: ('1', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.450
# item: ('Not Entered', '1', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.450
# item: ('1', 'HUMAN', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.450
# item: ('Not Entered', '1', 'HUMAN', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.450
# item: ('1', 'Not Applicable', 'Going Straight Ahead') , 0.470
# item: ('', '1', 'HUMAN', 'Going Straight Ahead') , 0.470
# item: ('1', 'HUMAN', 'Not Applicable', 'Going Straight Ahead') , 0.470
# item: ('1', 'Not Entered', 'Not Applicable', 'Going Straight Ahead') , 0.470
# item: ('', 'Not Entered', '1', 'HUMAN', 'Going Straight Ahead') , 0.470
# item: ('Not Entered', '1', 'HUMAN', 'Not Applicable', 'Going Straight Ahead') , 0.470
# item: ('', '1', 'HUMAN', '2013', 'Going Straight Ahead') , 0.470
# item: ('', 'Not Entered', '1', 'HUMAN', '2013', 'Going Straight Ahead') , 0.470
# item: ('', '1', 'Going Straight Ahead') , 0.480
# item: ('', '1', 'Not Entered', 'Going Straight Ahead') , 0.480
# item: ('', '1', '2013', 'Going Straight Ahead') , 0.480
# item: ('', 'Not Entered', '1', '2013', 'Going Straight Ahead') , 0.480
# item: ('1', 'HUMAN', '2013', 'Going Straight Ahead') , 0.490
# item: ('Not Entered', '1', 'HUMAN', '2013', 'Going Straight Ahead') , 0.490
# item: ('1', '2013', 'Going Straight Ahead') , 0.500
# item: ('1', 'Not Entered', '2013', 'Going Straight Ahead') , 0.500
# item: ('', 'Not Applicable', 'Going Straight Ahead') , 0.520
# item: ('', 'HUMAN', 'Not Applicable', 'Going Straight Ahead') , 0.520
# item: ('', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.520
# item: ('', 'Not Entered', 'Not Applicable', 'Going Straight Ahead') , 0.520
# item: ('', 'Not Entered', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.520
# item: ('', 'Not Entered', 'HUMAN', 'Not Applicable', 'Going Straight Ahead') , 0.520
# item: ('', 'HUMAN', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.520
# item: ('', 'Not Entered', 'HUMAN', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.520
# item: ('Not Applicable', '2013', 'Going Straight Ahead') , 0.530
# item: ('1', 'HUMAN', 'Going Straight Ahead') , 0.530
# item: ('HUMAN', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.530
# item: ('1', 'HUMAN', 'Not Entered', 'Going Straight Ahead') , 0.530
# item: ('Not Entered', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.530
# item: ('Not Entered', 'HUMAN', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.530
# item: ('1', 'Going Straight Ahead') , 0.540
# item: ('1', 'Not Entered', 'Going Straight Ahead') , 0.540
# item: ('', 'HUMAN', 'Going Straight Ahead') , 0.550
# item: ('', 'HUMAN', 'Not Entered', 'Going Straight Ahead') , 0.550
# item: ('', 'HUMAN', '2013', 'Going Straight Ahead') , 0.550
# item: ('', 'Not Entered', 'HUMAN', '2013', 'Going Straight Ahead') , 0.550
# item: ('', 'Going Straight Ahead') , 0.560
# item: ('Not Applicable', 'Going Straight Ahead') , 0.560
# item: ('Not Entered', 'Not Applicable', 'Going Straight Ahead') , 0.560
# item: ('', '2013', 'Going Straight Ahead') , 0.560
# item: ('Not Applicable', 'HUMAN', 'Going Straight Ahead') , 0.560
# item: ('', 'Not Entered', 'Going Straight Ahead') , 0.560
# item: ('HUMAN', 'Not Entered', 'Not Applicable', 'Going Straight Ahead') , 0.560
# item: ('', 'Not Entered', '2013', 'Going Straight Ahead') , 0.560
# item: ('HUMAN', '2013', 'Going Straight Ahead') , 0.570
# item: ('HUMAN', 'Not Entered', '2013', 'Going Straight Ahead') , 0.570
# item: ('2013', 'Going Straight Ahead') , 0.580
# item: ('Not Entered', '2013', 'Going Straight Ahead') , 0.580
# item: ('HUMAN', 'Going Straight Ahead') , 0.620
# item: ('Not Entered', 'HUMAN', 'Going Straight Ahead') , 0.620
# item: ('Going Straight Ahead',) , 0.630
# item: ('Not Entered', 'Going Straight Ahead') , 0.630
# item: ('1', '', 'Not Applicable') , 0.630
# item: ('1', '', 'Not Entered', 'Not Applicable') , 0.630
# item: ('', '1', 'Not Applicable', '2013') , 0.630
# item: ('1', '', 'HUMAN', 'Not Applicable') , 0.630
# item: ('', '1', 'HUMAN', 'Not Applicable', '2013') , 0.630
# item: ('', 'Not Entered', '1', 'HUMAN', 'Not Applicable') , 0.630
# item: ('', 'Not Entered', '1', 'Not Applicable', '2013') , 0.630
# item: ('', 'Not Entered', '1', 'HUMAN', 'Not Applicable', '2013') , 0.630
# item: ('1', 'Not Applicable', '2013') , 0.650
# item: ('1', 'Not Entered', 'Not Applicable', '2013') , 0.650
# item: ('1', 'HUMAN', 'Not Applicable', '2013') , 0.650
# item: ('Not Entered', '1', 'HUMAN', 'Not Applicable', '2013') , 0.650
# item: ('', '1', 'HUMAN') , 0.670
# item: ('', '1', 'HUMAN', '2013') , 0.670
# item: ('', '1', 'HUMAN', 'Not Entered') , 0.670
# item: ('', 'Not Entered', '1', 'HUMAN', '2013') , 0.670
# item: ('', '1') , 0.680
# item: ('1', '', '2013') , 0.680
# item: ('1', 'Not Entered', '') , 0.680
# item: ('1', '', 'Not Entered', '2013') , 0.680
# item: ('1', 'Not Applicable') , 0.690
# item: ('1', 'Not Entered', 'Not Applicable') , 0.690
# item: ('1', 'Not Applicable', 'HUMAN') , 0.690
# item: ('1', 'HUMAN', 'Not Entered', 'Not Applicable') , 0.690
# item: ('1', 'HUMAN', '2013') , 0.700
# item: ('1', 'HUMAN', 'Not Entered', '2013') , 0.700
# item: ('1', '2013') , 0.710
# item: ('1', 'Not Entered', '2013') , 0.710
# item: ('1', 'HUMAN') , 0.770
# item: ('1', 'Not Entered', 'HUMAN') , 0.770
# item: ('1',) , 0.780
# item: ('1', 'Not Entered') , 0.780
# item: ('', 'Not Applicable') , 0.820
# item: ('', 'Not Applicable', '2013') , 0.820
# item: ('', 'Not Entered', 'Not Applicable') , 0.820
# item: ('', 'Not Applicable', 'HUMAN') , 0.820
# item: ('', 'Not Entered', 'Not Applicable', '2013') , 0.820
# item: ('', 'HUMAN', 'Not Applicable', '2013') , 0.820
# item: ('', 'HUMAN', 'Not Entered', 'Not Applicable') , 0.820
# item: ('', 'Not Entered', 'HUMAN', 'Not Applicable', '2013') , 0.820
# item: ('Not Applicable', '2013') , 0.840
# item: ('Not Entered', 'Not Applicable', '2013') , 0.840
# item: ('Not Applicable', 'HUMAN', '2013') , 0.840
# item: ('HUMAN', 'Not Entered', 'Not Applicable', '2013') , 0.840
# item: ('', 'HUMAN') , 0.860
# item: ('', '2013', 'HUMAN') , 0.860
# item: ('', 'Not Entered', 'HUMAN') , 0.860
# item: ('', 'HUMAN', 'Not Entered', '2013') , 0.860
# item: ('',) , 0.870
# item: ('', 'Not Entered') , 0.870
# item: ('', '2013') , 0.870
# item: ('', 'Not Entered', '2013') , 0.870
# item: ('HUMAN', '2013') , 0.890
# item: ('Not Entered', '2013', 'HUMAN') , 0.890
# item: ('2013',) , 0.900
# item: ('Not Applicable',) , 0.900
# item: ('Not Entered', 'Not Applicable') , 0.900
# item: ('Not Applicable', 'HUMAN') , 0.900
# item: ('Not Entered', '2013') , 0.900
# item: ('Not Entered', 'Not Applicable', 'HUMAN') , 0.900
# item: ('HUMAN',) , 0.980
# item: ('Not Entered', 'HUMAN') , 0.980
# item: ('Not Entered',) , 0.990
#
# ------------------------ RULES:
# Rule: ('1', 'NY') ==> ('',) , 0.600
# Rule: ('1', 'NY') ==> ('', '2013') , 0.600
# Rule: ('1', 'NY') ==> ('', 'HUMAN') , 0.600
# Rule: ('1', 'NY', 'HUMAN') ==> ('',) , 0.600
# Rule: ('1', 'NY') ==> ('', 'Not Entered') , 0.600
# Rule: ('1', 'NY', 'Not Entered') ==> ('',) , 0.600
# Rule: ('1', '4 DOOR SEDAN', '2013') ==> ('Not Applicable', 'Going Straight Ahead') , 0.600
# Rule: ('1', 'NY') ==> ('', 'Not Entered', 'HUMAN') , 0.600
# Rule: ('1', 'Not Entered', 'NY') ==> ('', 'HUMAN') , 0.600
# Rule: ('1', 'NY', 'HUMAN') ==> ('', 'Not Entered') , 0.600
# Rule: ('1', 'Not Entered', 'HUMAN', 'NY') ==> ('',) , 0.600
# Rule: ('', '1', '4 DOOR SEDAN') ==> ('Not Applicable', 'Going Straight Ahead') , 0.600
# Rule: ('1', 'NY') ==> ('', 'Not Entered', '2013') , 0.600
# Rule: ('1', 'Not Entered', 'NY') ==> ('', '2013') , 0.600
# Rule: ('1', 'NY') ==> ('', '2013', 'HUMAN') , 0.600
# Rule: ('1', 'NY', 'HUMAN') ==> ('', '2013') , 0.600
# Rule: ('', '1', '4 DOOR SEDAN') ==> ('Not Applicable', 'HUMAN', 'Going Straight Ahead') , 0.600
# Rule: ('', '1', '4 DOOR SEDAN', 'HUMAN') ==> ('Not Applicable', 'Going Straight Ahead') , 0.600
# Rule: ('', '1', '4 DOOR SEDAN') ==> ('Not Entered', 'Not Applicable', 'Going Straight Ahead') , 0.600
# Rule: ('', 'Not Entered', '1', '4 DOOR SEDAN') ==> ('Not Applicable', 'Going Straight Ahead') , 0.600
# Rule: ('1', 'NY') ==> ('', 'Not Entered', '2013', 'HUMAN') , 0.600
# Rule: ('1', 'Not Entered', 'NY') ==> ('', '2013', 'HUMAN') , 0.600
# Rule: ('1', 'NY', 'HUMAN') ==> ('', 'Not Entered', '2013') , 0.600
# Rule: ('1', 'Not Entered', 'HUMAN', 'NY') ==> ('', '2013') , 0.600
# Rule: ('', '1', '4 DOOR SEDAN') ==> ('Not Applicable', '2013', 'Going Straight Ahead') , 0.600
# Rule: ('1', '4 DOOR SEDAN', '2013') ==> ('', 'Not Applicable', 'Going Straight Ahead') , 0.600
# Rule: ('', '1', '4 DOOR SEDAN', '2013') ==> ('Not Applicable', 'Going Straight Ahead') , 0.600
# Rule: ('1', '4 DOOR SEDAN', '2013') ==> ('Not Applicable', 'HUMAN', 'Going Straight Ahead') , 0.600
# Rule: ('1', '2013', '4 DOOR SEDAN', 'HUMAN') ==> ('Not Applicable', 'Going Straight Ahead') , 0.600
# Rule: ('1', '4 DOOR SEDAN', '2013') ==> ('Not Entered', 'Not Applicable', 'Going Straight Ahead') , 0.600
# Rule: ('1', 'Not Entered', '4 DOOR SEDAN', '2013') ==> ('Not Applicable', 'Going Straight Ahead') , 0.600
# Rule: ('', '1', '4 DOOR SEDAN') ==> ('Not Entered', 'Not Applicable', 'HUMAN', 'Going Straight Ahead') , 0.600
# Rule: ('', 'Not Entered', '1', '4 DOOR SEDAN') ==> ('Not Applicable', 'HUMAN', 'Going Straight Ahead') , 0.600
# Rule: ('', '1', '4 DOOR SEDAN', 'HUMAN') ==> ('Not Entered', 'Not Applicable', 'Going Straight Ahead') , 0.600
# Rule: ('', 'Not Entered', '1', '4 DOOR SEDAN', 'HUMAN') ==> ('Not Applicable', 'Going Straight Ahead') , 0.600
# Rule: ('1', '4 DOOR SEDAN', '2013') ==> ('Not Entered', 'Not Applicable', 'HUMAN', 'Going Straight Ahead') , 0.600
# Rule: ('1', 'Not Entered', '4 DOOR SEDAN', '2013') ==> ('Not Applicable', 'HUMAN', 'Going Straight Ahead') , 0.600
# Rule: ('1', '2013', '4 DOOR SEDAN', 'HUMAN') ==> ('Not Entered', 'Not Applicable', 'Going Straight Ahead') , 0.600
# Rule: ('1', 'Not Entered', '2013', '4 DOOR SEDAN', 'HUMAN') ==> ('Not Applicable', 'Going Straight Ahead') , 0.600
# Rule: ('', '1', '4 DOOR SEDAN') ==> ('Not Entered', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.600
# Rule: ('1', '4 DOOR SEDAN', '2013') ==> ('', 'Not Entered', 'Not Applicable', 'Going Straight Ahead') , 0.600
# Rule: ('', 'Not Entered', '1', '4 DOOR SEDAN') ==> ('Not Applicable', '2013', 'Going Straight Ahead') , 0.600
# Rule: ('', '1', '4 DOOR SEDAN', '2013') ==> ('Not Entered', 'Not Applicable', 'Going Straight Ahead') , 0.600
# Rule: ('1', 'Not Entered', '4 DOOR SEDAN', '2013') ==> ('', 'Not Applicable', 'Going Straight Ahead') , 0.600
# Rule: ('', 'Not Entered', '1', '4 DOOR SEDAN', '2013') ==> ('Not Applicable', 'Going Straight Ahead') , 0.600
# Rule: ('', '1', '4 DOOR SEDAN') ==> ('Not Applicable', '2013', 'HUMAN', 'Going Straight Ahead') , 0.600
# Rule: ('1', '4 DOOR SEDAN', '2013') ==> ('', 'Not Applicable', 'HUMAN', 'Going Straight Ahead') , 0.600
# Rule: ('', '1', '4 DOOR SEDAN', 'HUMAN') ==> ('Not Applicable', '2013', 'Going Straight Ahead') , 0.600
# Rule: ('', '1', '4 DOOR SEDAN', '2013') ==> ('Not Applicable', 'HUMAN', 'Going Straight Ahead') , 0.600
# Rule: ('1', '2013', '4 DOOR SEDAN', 'HUMAN') ==> ('', 'Not Applicable', 'Going Straight Ahead') , 0.600
# Rule: ('', '1', '2013', '4 DOOR SEDAN', 'HUMAN') ==> ('Not Applicable', 'Going Straight Ahead') , 0.600
# Rule: ('', '1', '4 DOOR SEDAN') ==> ('Not Entered', 'Not Applicable', '2013', 'HUMAN', 'Going Straight Ahead') , 0.600
# Rule: ('1', '4 DOOR SEDAN', '2013') ==> ('', 'Not Entered', 'Not Applicable', 'HUMAN', 'Going Straight Ahead') , 0.600
# Rule: ('', 'Not Entered', '1', '4 DOOR SEDAN') ==> ('Not Applicable', '2013', 'HUMAN', 'Going Straight Ahead') , 0.600
# Rule: ('', '1', '4 DOOR SEDAN', 'HUMAN') ==> ('Not Entered', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.600
# Rule: ('', '1', '4 DOOR SEDAN', '2013') ==> ('Not Entered', 'Not Applicable', 'HUMAN', 'Going Straight Ahead') , 0.600
# Rule: ('1', 'Not Entered', '4 DOOR SEDAN', '2013') ==> ('', 'Not Applicable', 'HUMAN', 'Going Straight Ahead') , 0.600
# Rule: ('1', '2013', '4 DOOR SEDAN', 'HUMAN') ==> ('', 'Not Entered', 'Not Applicable', 'Going Straight Ahead') , 0.600
# Rule: ('', 'Not Entered', '1', '4 DOOR SEDAN', 'HUMAN') ==> ('Not Applicable', '2013', 'Going Straight Ahead') , 0.600
# Rule: ('', 'Not Entered', '1', '4 DOOR SEDAN', '2013') ==> ('Not Applicable', 'HUMAN', 'Going Straight Ahead') , 0.600
# Rule: ('', '1', '2013', '4 DOOR SEDAN', 'HUMAN') ==> ('Not Entered', 'Not Applicable', 'Going Straight Ahead') , 0.600
# Rule: ('1', 'Not Entered', '2013', '4 DOOR SEDAN', 'HUMAN') ==> ('', 'Not Applicable', 'Going Straight Ahead') , 0.600
# Rule: ('', '4 DOOR SEDAN', 'Not Entered', '1', 'HUMAN', '2013') ==> ('Not Applicable', 'Going Straight Ahead') , 0.600
# Rule: ('1',) ==> ('Not Applicable', 'Going Straight Ahead') , 0.603
# Rule: ('1',) ==> ('', 'HUMAN', 'Going Straight Ahead') , 0.603
# Rule: ('1',) ==> ('Not Applicable', 'HUMAN', 'Going Straight Ahead') , 0.603
# Rule: ('1',) ==> ('Not Entered', 'Not Applicable', 'Going Straight Ahead') , 0.603
# Rule: ('1', 'Not Entered') ==> ('Not Applicable', 'Going Straight Ahead') , 0.603
# Rule: ('1',) ==> ('', 'Not Entered', 'HUMAN', 'Going Straight Ahead') , 0.603
# Rule: ('1', 'Not Entered') ==> ('', 'HUMAN', 'Going Straight Ahead') , 0.603
# Rule: ('1',) ==> ('Not Entered', 'Not Applicable', 'HUMAN', 'Going Straight Ahead') , 0.603
# Rule: ('1', 'Not Entered') ==> ('Not Applicable', 'HUMAN', 'Going Straight Ahead') , 0.603
# Rule: ('1',) ==> ('', '2013', 'HUMAN', 'Going Straight Ahead') , 0.603
# Rule: ('1',) ==> ('', 'Not Entered', '2013', 'HUMAN', 'Going Straight Ahead') , 0.603
# Rule: ('1', 'Not Entered') ==> ('', '2013', 'HUMAN', 'Going Straight Ahead') , 0.603
# Rule: ('4 DOOR SEDAN',) ==> ('Going Straight Ahead',) , 0.605
# Rule: ('4 DOOR SEDAN',) ==> ('Not Entered', 'Going Straight Ahead') , 0.605
# Rule: ('Not Entered', '4 DOOR SEDAN') ==> ('Going Straight Ahead',) , 0.605
# Rule: ('4 DOOR SEDAN',) ==> ('HUMAN', 'Going Straight Ahead') , 0.605
# Rule: ('4 DOOR SEDAN', 'HUMAN') ==> ('Going Straight Ahead',) , 0.605
# Rule: ('', 'HUMAN') ==> ('Not Applicable', 'Going Straight Ahead') , 0.605
# Rule: ('4 DOOR SEDAN',) ==> ('Not Entered', 'HUMAN', 'Going Straight Ahead') , 0.605
# Rule: ('4 DOOR SEDAN', 'HUMAN') ==> ('Not Entered', 'Going Straight Ahead') , 0.605
# Rule: ('Not Entered', '4 DOOR SEDAN') ==> ('HUMAN', 'Going Straight Ahead') , 0.605
# Rule: ('Not Entered', '4 DOOR SEDAN', 'HUMAN') ==> ('Going Straight Ahead',) , 0.605
# Rule: ('', 'HUMAN') ==> ('Not Entered', 'Not Applicable', 'Going Straight Ahead') , 0.605
# Rule: ('', 'Not Entered', 'HUMAN') ==> ('Not Applicable', 'Going Straight Ahead') , 0.605
# Rule: ('', 'HUMAN') ==> ('Not Applicable', '2013', 'Going Straight Ahead') , 0.605
# Rule: ('', '2013', 'HUMAN') ==> ('Not Applicable', 'Going Straight Ahead') , 0.605
# Rule: ('', 'HUMAN') ==> ('Not Entered', 'Not Applicable', '2013', 'Going Straight Ahead') , 0.605
# Rule: ('', 'Not Entered', 'HUMAN') ==> ('Not Applicable', '2013', 'Going Straight Ahead') , 0.605
# Rule: ('', '2013', 'HUMAN') ==> ('Not Entered', 'Not Applicable', 'Going Straight Ahead') , 0.605
# Rule: ('', 'Not Entered', '2013', 'HUMAN') ==> ('Not Applicable', 'Going Straight Ahead') , 0.605
# Rule: ('1', '4 DOOR SEDAN') ==> ('2013', 'Going Straight Ahead') , 0.606
# Rule: ('1', '4 DOOR SEDAN') ==> ('Not Applicable', 'Going Straight Ahead') , 0.606
# Rule: ('1', '4 DOOR SEDAN') ==> ('', 'Going Straight Ahead') , 0.606
# Rule: ('1', '4 DOOR SEDAN') ==> ('Not Applicable', 'HUMAN', 'Going Straight Ahead') , 0.606
# Rule: ('1', '4 DOOR SEDAN', 'HUMAN') ==> ('Not Applicable', 'Going Straight Ahead') , 0.606
# Rule: ('1', '4 DOOR SEDAN') ==> ('2013', 'HUMAN', 'Going Straight Ahead') , 0.606
# Rule: ('1', '4 DOOR SEDAN', 'HUMAN') ==> ('2013', 'Going Straight Ahead') , 0.606
# Rule: ('1', '4 DOOR SEDAN') ==> ('', 'Not Entered', 'Going Straight Ahead') , 0.606
# Rule: ('1', 'Not Entered', '4 DOOR SEDAN') ==> ('', 'Going Straight Ahead') , 0.606
# Rule: ('1', '4 DOOR SEDAN') ==> ('Not Entered', '2013', 'Going Straight Ahead') , 0.606
# Rule: ('1', 'Not Entered', '4 DOOR SEDAN') ==> ('2013', 'Going Straight Ahead') , 0.606
# Rule: ('1', '4 DOOR SEDAN') ==> ('', '2013', 'Going Straight Ahead') , 0.606
# Rule: ('1', '4 DOOR SEDAN') ==> ('', 'HUMAN', 'Going Straight Ahead') , 0.606
# Rule: ('1', '4 DOOR SEDAN', 'HUMAN') ==> ('', 'Going Straight Ahead') , 0.606
# Rule: ('1', '4 DOOR SEDAN') ==> ('Not Entered', 'Not Applicable', 'Going Straight Ahead') , 0.606
# Rule: ('1', 'Not Entered', '4 DOOR SEDAN') ==> ('Not Applicable', 'Going Straight Ahead') , 0.606
# Rule: ('1', '4 DOOR SEDAN') ==> ('', '2013', 'HUMAN', 'Going Straight Ahead') , 0.606
# Rule: ('1', '4 DOOR SEDAN', 'HUMAN') ==> ('', '2013', 'Going Straight Ahead') , 0.606
# Rule: ('1', '4 DOOR SEDAN') ==> ('', 'Not Entered', '2013', 'Going Straight Ahead') , 0.606
# Rule: ('1', 'Not Entered', '4 DOOR SEDAN') ==> ('', '2013', 'Going Straight Ahead') , 0.606
# Rule: ('1', '4 DOOR SEDAN') ==> ('', 'Not Entered', 'HUMAN', 'Going Straight Ahead') , 0.606
# Rule: ('1', 'Not Entered', '4 DOOR SEDAN') ==> ('', 'HUMAN', 'Going Straight Ahead') , 0.606
# Rule: ('1', '4 DOOR SEDAN', 'HUMAN') ==> ('', 'Not Entered', 'Going Straight Ahead') , 0.606
# Rule: ('1', 'Not Entered', '4 DOOR SEDAN', 'HUMAN') ==> ('', 'Going Straight Ahead') , 0.606
# Rule: ('1', '4 DOOR SEDAN') ==> ('Not Entered', '2013', 'HUMAN', 'Going Straight Ahead') , 0.606
# Rule: ('1', 'Not Entered', '4 DOOR SEDAN') ==> ('2013', 'HUMAN', 'Going Straight Ahead') , 0.606
# ...
# Rule: ('2013', 'Not Applicable', '4 DOOR SEDAN', 'HUMAN', 'Going Straight Ahead') ==> ('Not Entered',) , 1.000
# Rule: ('1', 'Not Applicable', '4 DOOR SEDAN', '2013', 'Going Straight Ahead') ==> ('HUMAN',) , 1.000
# Rule: ('1', 'Not Applicable', 'North') ==> ('', '2013', 'HUMAN') , 1.000
# Rule: ('', '1', 'North', 'Not Applicable') ==> ('2013', 'HUMAN') , 1.000
# Rule: ('1', 'Not Applicable', 'North', 'HUMAN') ==> ('', '2013') , 1.000
# Rule: ('1', 'Not Applicable', 'North', '2013') ==> ('', 'HUMAN') , 1.000
# Rule: ('', '1', 'North', 'Not Applicable', 'HUMAN') ==> ('2013',) , 1.000
# Rule: ('', '1', 'North', 'Not Applicable', '2013') ==> ('HUMAN',) , 1.000
# Rule: ('1', 'Not Applicable', 'North', '2013', 'HUMAN') ==> ('',) , 1.000
# Rule: ('1', 'Not Applicable', 'North') ==> ('Not Entered', '2013', 'HUMAN') , 1.000
# Rule: ('1', 'Not Entered', 'North', 'Not Applicable') ==> ('2013', 'HUMAN') , 1.000
# Rule: ('1', 'Not Applicable', 'North', 'HUMAN') ==> ('Not Entered', '2013') , 1.000
# Rule: ('1', 'Not Applicable', 'North', '2013') ==> ('Not Entered', 'HUMAN') , 1.000
# Rule: ('1', 'Not Entered', 'North', 'Not Applicable', 'HUMAN') ==> ('2013',) , 1.000
# Rule: ('1', 'Not Entered', 'North', 'Not Applicable', '2013') ==> ('HUMAN',) , 1.000
# Rule: ('1', 'Not Applicable', 'North', '2013', 'HUMAN') ==> ('Not Entered',) , 1.000
# Rule: ('North', 'Going Straight Ahead') ==> ('', 'Not Entered', '2013', 'HUMAN') , 1.000
# Rule: ('', 'North', 'Going Straight Ahead') ==> ('Not Entered', '2013', 'HUMAN') , 1.000
# Rule: ('Not Entered', 'North', 'Going Straight Ahead') ==> ('', '2013', 'HUMAN') , 1.000
# Rule: ('North', 'HUMAN', 'Going Straight Ahead') ==> ('', 'Not Entered', '2013') , 1.000
# Rule: ('North', '2013', 'Going Straight Ahead') ==> ('', 'Not Entered', 'HUMAN') , 1.000
# Rule: ('', 'Not Entered', 'North', 'Going Straight Ahead') ==> ('2013', 'HUMAN') , 1.000
# Rule: ('', 'North', 'HUMAN', 'Going Straight Ahead') ==> ('Not Entered', '2013') , 1.000
# Rule: ('', 'North', '2013', 'Going Straight Ahead') ==> ('Not Entered', 'HUMAN') , 1.000
# Rule: ('Not Entered', 'North', 'HUMAN', 'Going Straight Ahead') ==> ('', '2013') , 1.000
# Rule: ('Not Entered', 'North', '2013', 'Going Straight Ahead') ==> ('', 'HUMAN') , 1.000
# Rule: ('North', '2013', 'HUMAN', 'Going Straight Ahead') ==> ('', 'Not Entered') , 1.000
# Rule: ('', 'Not Entered', 'North', 'HUMAN', 'Going Straight Ahead') ==> ('2013',) , 1.000
# Rule: ('', 'Not Entered', 'North', '2013', 'Going Straight Ahead') ==> ('HUMAN',) , 1.000
# Rule: ('', 'North', '2013', 'HUMAN', 'Going Straight Ahead') ==> ('Not Entered',) , 1.000
# Rule: ('Not Entered', 'North', '2013', 'HUMAN', 'Going Straight Ahead') ==> ('',) , 1.000
# Rule: ('West', 'Not Applicable') ==> ('', 'Not Entered', '2013', 'HUMAN') , 1.000
# Rule: ('', 'West', 'Not Applicable') ==> ('Not Entered', '2013', 'HUMAN') , 1.000
# Rule: ('Not Entered', 'Not Applicable', 'West') ==> ('', '2013', 'HUMAN') , 1.000
# Rule: ('West', 'Not Applicable', 'HUMAN') ==> ('', 'Not Entered', '2013') , 1.000
# Rule: ('West', 'Not Applicable', '2013') ==> ('', 'Not Entered', 'HUMAN') , 1.000
# Rule: ('', 'Not Entered', 'Not Applicable', 'West') ==> ('2013', 'HUMAN') , 1.000
# Rule: ('', 'West', 'Not Applicable', 'HUMAN') ==> ('Not Entered', '2013') , 1.000
# Rule: ('', 'West', 'Not Applicable', '2013') ==> ('Not Entered', 'HUMAN') , 1.000
# Rule: ('Not Entered', 'Not Applicable', 'HUMAN', 'West') ==> ('', '2013') , 1.000
# Rule: ('Not Entered', 'Not Applicable', '2013', 'West') ==> ('', 'HUMAN') , 1.000
# Rule: ('West', 'Not Applicable', '2013', 'HUMAN') ==> ('', 'Not Entered') , 1.000
# Rule: ('', 'Not Entered', 'Not Applicable', 'HUMAN', 'West') ==> ('2013',) , 1.000
# Rule: ('', 'Not Entered', 'Not Applicable', '2013', 'West') ==> ('HUMAN',) , 1.000
# Rule: ('', 'West', 'Not Applicable', '2013', 'HUMAN') ==> ('Not Entered',) , 1.000
# Rule: ('Not Entered', 'Not Applicable', '2013', 'HUMAN', 'West') ==> ('',) , 1.000
# Rule: ('1', 'Not Applicable', '4 DOOR SEDAN', '2013', 'Going Straight Ahead') ==> ('Not Entered',) , 1.000
# Rule: ('', 'Not Applicable', 'South') ==> ('Not Entered', '2013', 'HUMAN') , 1.000
# Rule: ('Not Applicable', '2013', 'South') ==> ('', 'Not Entered', 'HUMAN') , 1.000
# Rule: ('', 'Not Entered', 'Not Applicable', 'South') ==> ('2013', 'HUMAN') , 1.000
# Rule: ('', 'Not Applicable', 'HUMAN', 'South') ==> ('Not Entered', '2013') , 1.000
# Rule: ('', 'Not Applicable', '2013', 'South') ==> ('Not Entered', 'HUMAN') , 1.000
# Rule: ('Not Entered', 'Not Applicable', '2013', 'South') ==> ('', 'HUMAN') , 1.000
# Rule: ('2013', 'Not Applicable', 'HUMAN', 'South') ==> ('', 'Not Entered') , 1.000
# Rule: ('', 'Not Entered', 'Not Applicable', 'HUMAN', 'South') ==> ('2013',) , 1.000
# Rule: ('', 'Not Entered', 'Not Applicable', '2013', 'South') ==> ('HUMAN',) , 1.000
# Rule: ('', '2013', 'Not Applicable', 'HUMAN', 'South') ==> ('Not Entered',) , 1.000
# Rule: ('Not Entered', '2013', 'Not Applicable', 'HUMAN', 'South') ==> ('',) , 1.000
# Rule: ('', '1', 'Not Applicable') ==> ('Not Entered', '2013', 'HUMAN') , 1.000
# Rule: ('', 'Not Entered', '1', 'Not Applicable') ==> ('2013', 'HUMAN') , 1.000
# Rule: ('', '1', 'Not Applicable', 'HUMAN') ==> ('Not Entered', '2013') , 1.000
# Rule: ('', '1', 'Not Applicable', '2013') ==> ('Not Entered', 'HUMAN') , 1.000
# Rule: ('', 'Not Entered', '1', 'Not Applicable', 'HUMAN') ==> ('2013',) , 1.000
# Rule: ('', 'Not Entered', '1', 'Not Applicable', '2013') ==> ('HUMAN',) , 1.000
# Rule: ('', '1', 'Not Applicable', '2013', 'HUMAN') ==> ('Not Entered',) , 1.000
# Rule: ('', '1', 'Not Applicable', '4 DOOR SEDAN') ==> ('Not Entered', '2013') , 1.000
# Rule: ('1', 'Not Applicable', '4 DOOR SEDAN', '2013') ==> ('', 'Not Entered') , 1.000
# Rule: ('', 'Not Entered', '1', 'Not Applicable', '4 DOOR SEDAN') ==> ('2013',) , 1.000
# Rule: ('', '1', 'Not Applicable', '4 DOOR SEDAN', '2013') ==> ('Not Entered',) , 1.000
# Rule: ('1', 'Not Entered', 'Not Applicable', '4 DOOR SEDAN', '2013') ==> ('',) , 1.000
# Rule: ('', '1', '4 DOOR SEDAN') ==> ('Not Entered', '2013', 'HUMAN') , 1.000
# Rule: ('1', '4 DOOR SEDAN', '2013') ==> ('', 'Not Entered', 'HUMAN') , 1.000
# Rule: ('', 'Not Entered', '1', '4 DOOR SEDAN') ==> ('2013', 'HUMAN') , 1.000
# Rule: ('', '1', '4 DOOR SEDAN', 'HUMAN') ==> ('Not Entered', '2013') , 1.000
# Rule: ('', '1', '4 DOOR SEDAN', '2013') ==> ('Not Entered', 'HUMAN') , 1.000
# Rule: ('1', 'Not Entered', '4 DOOR SEDAN', '2013') ==> ('', 'HUMAN') , 1.000
# Rule: ('1', '2013', '4 DOOR SEDAN', 'HUMAN') ==> ('', 'Not Entered') , 1.000
# Rule: ('', 'Not Entered', '1', '4 DOOR SEDAN', 'HUMAN') ==> ('2013',) , 1.000
# Rule: ('', 'Not Entered', '1', '4 DOOR SEDAN', '2013') ==> ('HUMAN',) , 1.000
# Rule: ('', '1', '2013', '4 DOOR SEDAN', 'HUMAN') ==> ('Not Entered',) , 1.000
# Rule: ('1', 'Not Entered', '2013', '4 DOOR SEDAN', 'HUMAN') ==> ('',) , 1.000
# Rule: ('1', '4 DOOR SEDAN', '2013', 'Going Straight Ahead') ==> ('Not Entered', 'HUMAN') , 1.000
# Rule: ('1', 'Not Entered', '4 DOOR SEDAN', '2013', 'Going Straight Ahead') ==> ('HUMAN',) , 1.000
# Rule: ('1', '2013', '4 DOOR SEDAN', 'HUMAN', 'Going Straight Ahead') ==> ('Not Entered',) , 1.000
# Rule: ('1', 'Not Applicable', '4 DOOR SEDAN', 'Going Straight Ahead') ==> ('Not Entered', 'HUMAN') , 1.000
# Rule: ('1', 'Not Entered', 'Not Applicable', '4 DOOR SEDAN', 'Going Straight Ahead') ==> ('HUMAN',) , 1.000
# Rule: ('1', 'Not Applicable', '4 DOOR SEDAN', 'HUMAN', 'Going Straight Ahead') ==> ('Not Entered',) , 1.000
# Rule: ('', '1', 'Not Applicable', 'Going Straight Ahead') ==> ('Not Entered', '2013', 'HUMAN') , 1.000
# Rule: ('', 'Not Entered', '1', 'Not Applicable', 'Going Straight Ahead') ==> ('2013', 'HUMAN') , 1.000
# Rule: ('', '1', 'Not Applicable', 'HUMAN', 'Going Straight Ahead') ==> ('Not Entered', '2013') , 1.000
# Rule: ('', '1', 'Not Applicable', '2013', 'Going Straight Ahead') ==> ('Not Entered', 'HUMAN') , 1.000
# Rule: ('', 'Not Entered', '1', 'HUMAN', 'Not Applicable', 'Going Straight Ahead') ==> ('2013',) , 1.000
# Rule: ('', 'Not Entered', '1', 'Not Applicable', '2013', 'Going Straight Ahead') ==> ('HUMAN',) , 1.000
# Rule: ('', '1', 'HUMAN', 'Not Applicable', '2013', 'Going Straight Ahead') ==> ('Not Entered',) , 1.000
# Rule: ('', '1', 'Not Applicable', '4 DOOR SEDAN', 'Going Straight Ahead') ==> ('Not Entered', 'HUMAN') , 1.000
# Rule: ('', '4 DOOR SEDAN', 'Not Entered', '1', 'Not Applicable', 'Going Straight Ahead') ==> ('HUMAN',) , 1.000
# Rule: ('', '4 DOOR SEDAN', '1', 'HUMAN', 'Not Applicable', 'Going Straight Ahead') ==> ('Not Entered',) , 1.000
# Rule: ('1', 'Not Applicable', '4 DOOR SEDAN', '2013', 'Going Straight Ahead') ==> ('Not Entered', 'HUMAN') , 1.000
# Rule: ('4 DOOR SEDAN', 'Not Entered', '1', 'Not Applicable', '2013', 'Going Straight Ahead') ==> ('HUMAN',) , 1.000
# Rule: ('4 DOOR SEDAN', '1', 'HUMAN', 'Not Applicable', '2013', 'Going Straight Ahead') ==> ('Not Entered',) , 1.000
# Rule: ('1', 'Not Applicable', 'North') ==> ('', 'Not Entered', '2013', 'HUMAN') , 1.000
# Rule: ('', '1', 'North', 'Not Applicable') ==> ('Not Entered', '2013', 'HUMAN') , 1.000
# Rule: ('1', 'Not Entered', 'North', 'Not Applicable') ==> ('', '2013', 'HUMAN') , 1.000
# Rule: ('1', 'Not Applicable', 'North', 'HUMAN') ==> ('', 'Not Entered', '2013') , 1.000
# Rule: ('1', 'Not Applicable', 'North', '2013') ==> ('', 'Not Entered', 'HUMAN') , 1.000
# Rule: ('', 'Not Entered', '1', 'North', 'Not Applicable') ==> ('2013', 'HUMAN') , 1.000
# Rule: ('', '1', 'North', 'Not Applicable', 'HUMAN') ==> ('Not Entered', '2013') , 1.000
# Rule: ('', '1', 'North', 'Not Applicable', '2013') ==> ('Not Entered', 'HUMAN') , 1.000
# Rule: ('1', 'Not Entered', 'North', 'Not Applicable', 'HUMAN') ==> ('', '2013') , 1.000
# Rule: ('1', 'Not Entered', 'North', 'Not Applicable', '2013') ==> ('', 'HUMAN') , 1.000
# Rule: ('1', 'Not Applicable', 'North', '2013', 'HUMAN') ==> ('', 'Not Entered') , 1.000
# Rule: ('', 'North', 'Not Entered', '1', 'HUMAN', 'Not Applicable') ==> ('2013',) , 1.000
# Rule: ('', 'North', 'Not Entered', '1', 'Not Applicable', '2013') ==> ('HUMAN',) , 1.000
# Rule: ('', 'North', '1', 'HUMAN', 'Not Applicable', '2013') ==> ('Not Entered',) , 1.000
# Rule: ('North', 'Not Entered', '1', 'HUMAN', 'Not Applicable', '2013') ==> ('',) , 1.000
# Rule: ('', '1', 'Not Applicable', '4 DOOR SEDAN', 'Going Straight Ahead') ==> ('Not Entered', '2013') , 1.000
# Rule: ('1', 'Not Applicable', '4 DOOR SEDAN', '2013', 'Going Straight Ahead') ==> ('', 'Not Entered') , 1.000
# Rule: ('', '4 DOOR SEDAN', 'Not Entered', '1', 'Not Applicable', 'Going Straight Ahead') ==> ('2013',) , 1.000
# Rule: ('', '4 DOOR SEDAN', '1', 'Not Applicable', '2013', 'Going Straight Ahead') ==> ('Not Entered',) , 1.000
# Rule: ('4 DOOR SEDAN', 'Not Entered', '1', 'Not Applicable', '2013', 'Going Straight Ahead') ==> ('',) , 1.000
# Rule: ('', '1', 'Not Applicable', '4 DOOR SEDAN', 'Going Straight Ahead') ==> ('2013', 'HUMAN') , 1.000
# Rule: ('1', 'Not Applicable', '4 DOOR SEDAN', '2013', 'Going Straight Ahead') ==> ('', 'HUMAN') , 1.000
# Rule: ('', '4 DOOR SEDAN', '1', 'HUMAN', 'Not Applicable', 'Going Straight Ahead') ==> ('2013',) , 1.000
# Rule: ('', '4 DOOR SEDAN', '1', 'Not Applicable', '2013', 'Going Straight Ahead') ==> ('HUMAN',) , 1.000
# Rule: ('4 DOOR SEDAN', '1', 'HUMAN', 'Not Applicable', '2013', 'Going Straight Ahead') ==> ('',) , 1.000
# Rule: ('', '1', 'Not Applicable', '4 DOOR SEDAN') ==> ('Not Entered', '2013', 'HUMAN') , 1.000
# Rule: ('1', 'Not Applicable', '4 DOOR SEDAN', '2013') ==> ('', 'Not Entered', 'HUMAN') , 1.000
# Rule: ('', 'Not Entered', '1', 'Not Applicable', '4 DOOR SEDAN') ==> ('2013', 'HUMAN') , 1.000
# Rule: ('', '1', 'Not Applicable', '4 DOOR SEDAN', 'HUMAN') ==> ('Not Entered', '2013') , 1.000
# Rule: ('', '1', 'Not Applicable', '4 DOOR SEDAN', '2013') ==> ('Not Entered', 'HUMAN') , 1.000
# Rule: ('1', 'Not Entered', 'Not Applicable', '4 DOOR SEDAN', '2013') ==> ('', 'HUMAN') , 1.000
# Rule: ('1', '2013', 'Not Applicable', '4 DOOR SEDAN', 'HUMAN') ==> ('', 'Not Entered') , 1.000
# Rule: ('', '4 DOOR SEDAN', 'Not Entered', '1', 'HUMAN', 'Not Applicable') ==> ('2013',) , 1.000
# Rule: ('', '4 DOOR SEDAN', 'Not Entered', '1', 'Not Applicable', '2013') ==> ('HUMAN',) , 1.000
# Rule: ('', '4 DOOR SEDAN', '1', 'HUMAN', 'Not Applicable', '2013') ==> ('Not Entered',) , 1.000
# Rule: ('4 DOOR SEDAN', 'Not Entered', '1', 'HUMAN', 'Not Applicable', '2013') ==> ('',) , 1.000
# Rule: ('', 'Not Applicable', '4 DOOR SEDAN', 'Going Straight Ahead') ==> ('Not Entered', '2013', 'HUMAN') , 1.000
# Rule: ('Not Applicable', '4 DOOR SEDAN', '2013', 'Going Straight Ahead') ==> ('', 'Not Entered', 'HUMAN') , 1.000
# Rule: ('', 'Not Entered', 'Not Applicable', '4 DOOR SEDAN', 'Going Straight Ahead') ==> ('2013', 'HUMAN') , 1.000
# Rule: ('', 'Not Applicable', '4 DOOR SEDAN', 'HUMAN', 'Going Straight Ahead') ==> ('Not Entered', '2013') , 1.000
# Rule: ('', 'Not Applicable', '4 DOOR SEDAN', '2013', 'Going Straight Ahead') ==> ('Not Entered', 'HUMAN') , 1.000
# Rule: ('Not Entered', 'Not Applicable', '4 DOOR SEDAN', '2013', 'Going Straight Ahead') ==> ('', 'HUMAN') , 1.000
# Rule: ('2013', 'Not Applicable', '4 DOOR SEDAN', 'HUMAN', 'Going Straight Ahead') ==> ('', 'Not Entered') , 1.000
# Rule: ('', '4 DOOR SEDAN', 'Not Entered', 'HUMAN', 'Not Applicable', 'Going Straight Ahead') ==> ('2013',) , 1.000
# Rule: ('', '4 DOOR SEDAN', 'Not Entered', 'Not Applicable', '2013', 'Going Straight Ahead') ==> ('HUMAN',) , 1.000
# Rule: ('', '4 DOOR SEDAN', 'HUMAN', 'Not Applicable', '2013', 'Going Straight Ahead') ==> ('Not Entered',) , 1.000
# Rule: ('4 DOOR SEDAN', 'Not Entered', 'HUMAN', 'Not Applicable', '2013', 'Going Straight Ahead') ==> ('',) , 1.000
# Rule: ('', '1', '4 DOOR SEDAN', 'Going Straight Ahead') ==> ('Not Entered', '2013', 'HUMAN') , 1.000
# Rule: ('1', '4 DOOR SEDAN', '2013', 'Going Straight Ahead') ==> ('', 'Not Entered', 'HUMAN') , 1.000
# Rule: ('', 'Not Entered', '1', '4 DOOR SEDAN', 'Going Straight Ahead') ==> ('2013', 'HUMAN') , 1.000
# Rule: ('', '1', '4 DOOR SEDAN', 'HUMAN', 'Going Straight Ahead') ==> ('Not Entered', '2013') , 1.000
# Rule: ('', '1', '4 DOOR SEDAN', '2013', 'Going Straight Ahead') ==> ('Not Entered', 'HUMAN') , 1.000
# Rule: ('1', 'Not Entered', '4 DOOR SEDAN', '2013', 'Going Straight Ahead') ==> ('', 'HUMAN') , 1.000
# Rule: ('1', '2013', '4 DOOR SEDAN', 'HUMAN', 'Going Straight Ahead') ==> ('', 'Not Entered') , 1.000
# Rule: ('', '4 DOOR SEDAN', 'Not Entered', '1', 'HUMAN', 'Going Straight Ahead') ==> ('2013',) , 1.000
# Rule: ('', '4 DOOR SEDAN', 'Not Entered', '1', '2013', 'Going Straight Ahead') ==> ('HUMAN',) , 1.000
# Rule: ('', '4 DOOR SEDAN', '1', 'HUMAN', '2013', 'Going Straight Ahead') ==> ('Not Entered',) , 1.000
# Rule: ('4 DOOR SEDAN', 'Not Entered', '1', 'HUMAN', '2013', 'Going Straight Ahead') ==> ('',) , 1.000
# Rule: ('', '1', 'Not Applicable', '4 DOOR SEDAN', 'Going Straight Ahead') ==> ('Not Entered', '2013', 'HUMAN') , 1.000
# Rule: ('1', 'Not Applicable', '4 DOOR SEDAN', '2013', 'Going Straight Ahead') ==> ('', 'Not Entered', 'HUMAN') , 1.000
# Rule: ('', '4 DOOR SEDAN', 'Not Entered', '1', 'Not Applicable', 'Going Straight Ahead') ==> ('2013', 'HUMAN') , 1.000
# Rule: ('', '4 DOOR SEDAN', '1', 'HUMAN', 'Not Applicable', 'Going Straight Ahead') ==> ('Not Entered', '2013') , 1.000
# Rule: ('', '4 DOOR SEDAN', '1', 'Not Applicable', '2013', 'Going Straight Ahead') ==> ('Not Entered', 'HUMAN') , 1.000
# Rule: ('4 DOOR SEDAN', 'Not Entered', '1', 'Not Applicable', '2013', 'Going Straight Ahead') ==> ('', 'HUMAN') , 1.000
# Rule: ('4 DOOR SEDAN', '1', 'HUMAN', 'Not Applicable', '2013', 'Going Straight Ahead') ==> ('', 'Not Entered') , 1.000
# Rule: ('', '4 DOOR SEDAN', 'Not Entered', '1', 'HUMAN', 'Not Applicable', 'Going Straight Ahead') ==> ('2013',) , 1.000
# Rule: ('', '4 DOOR SEDAN', 'Not Entered', '1', 'Not Applicable', '2013', 'Going Straight Ahead') ==> ('HUMAN',) , 1.000
# Rule: ('', '4 DOOR SEDAN', '1', 'HUMAN', 'Not Applicable', '2013', 'Going Straight Ahead') ==> ('Not Entered',) , 1.000
# Rule: ('4 DOOR SEDAN', 'Not Entered', '1', 'HUMAN', 'Not Applicable', '2013', 'Going Straight Ahead') ==> ('',) , 1.000
#
# C:\Users\Vishnu\Documents\GitHub\big-data-python-class\Homeworks\Homework7>

# %%
# Copied from http://facweb.cs.depaul.edu/mobasher/classes/CSC478/Notes/IPython%20Notebook%20-%20Associations.html

# %%
import apriori as ap

# %%
L, support = ap.apriori(dataset,0.5)

# %%
print L
# Out:
# [[frozenset(['Entered,Going']), frozenset(['Ahead,Not']), frozenset(['Applicable,Not']), frozenset(['Straight'])], [frozenset(['Ahead,Not', 'Entered,Going']), frozenset(['Ahead,Not', 'Straight']), frozenset(['Straight', 'Entered,Going'])], [frozenset(['Ahead,Not', 'Straight', 'Entered,Going'])], []]

# %%
print support
# Out:
# {frozenset(['Entered,Northwest,Not']): 0.03, frozenset(['Entered,2000,NJ,1,,FRHT,HUMAN,Unsafe']): 0.01, frozenset(['2013,11622893,SUBURBAN,Not']): 0.01, frozenset(['Entered,2006,CT,1,,TOYT,HUMAN,Failure']): 0.01, frozenset(['Applicable,"Guide']): 0.01, frozenset(['Applicable,2G1WB5EK7B1']): 0.01, frozenset(["Entered,2010,PA,1,,NISS,ENVMT,Animal's"]): 0.01, frozenset(['Applicable,2MG3JM8A7DW']): 0.01, frozenset(['TRUCK,COMMERCIAL,Stopped']): 0.01, frozenset(['Entered,2007,CT,1,,VOLV,ENVMT,View']): 0.01, frozenset(['2013,11161588,4']): 0.01, frozenset(['Closely,Not']): 0.04, frozenset(['Occupants,Engine']): 0.01, frozenset(['Entered,2007,OH,1,,FORD,HUMAN,Unsafe']): 0.01, frozenset(['Entered,South,Gas,2003,NY,1,10,FORD,HUMAN,Unsafe']): 0.01, frozenset(['Applicable,1ETBX18H8YN']): 0.01, frozenset(['Entered,2013,NJ,1,,FORD,HUMAN,Driver']): 0.01, frozenset(['2013,10950672,SUBURBAN,Not']): 0.01, frozenset(['Entered,2011,CT,1,,HOND,HUMAN,Following']): 0.01, frozenset(['Entered,2004,NJ,1,,CHEV,HUMAN,Unsafe']): 0.01, frozenset(['Entered,2010,PA,1,,TOYT,HUMAN,Not']): 0.01, frozenset(['Applicable,2FMDK36C47B']): 0.01, frozenset(['2013,11558377,TRACTOR,Not']): 0.01, frozenset(['Object",']): 0.02, frozenset(['Entered,Stopped']): 0.03, frozenset(['2013,11132317,SUBURBAN,Not']): 0.01, frozenset(['Entered,2011,ME,1,,CADI,HUMAN,Prescription']): 0.01, frozenset(['2013,10809401,4']): 0.01, frozenset(['2013,11386243,TRACTOR,Not']): 0.01, frozenset(['Applicable,3N1AB61E38L']): 0.01, frozenset(['2013,11388795,4']): 0.01, frozenset(['Right-of-Way,HUMAN,Not']): 0.06, frozenset(['Prior']): 0.01, frozenset(['Inattention/Distraction*,Not']): 0.03, frozenset(['2013,10989070,TRACTOR,Not']): 0.01, frozenset(["Applicable,ENVMT,Animal's"]): 0.01, frozenset(['2013,11194330,4']): 0.01, frozenset(['2013,10890741,SUBURBAN,Not']): 0.01, frozenset(['Right-of-Way,HUMAN,Turning']): 0.01, frozenset(['2013,11085833,SUBURBAN,Not']): 0.01, frozenset(['2013,11386643,MOTORCYCLE,Not']): 0.01, frozenset(['Applicable,4T1BG22K7VU']): 0.01, frozenset(['2012,10001283,4']): 0.01, frozenset(['Entered,Starting']): 0.01, frozenset(['Entered,2007,NY,1,,TOYT,ENVMT,Pavement']): 0.01, frozenset(['Entered,2013,NY,1,,MCIN,HUMAN,Following']): 0.01, frozenset(['Entered,2013,NY,2,,HYUN,HUMAN,Following']): 0.01, frozenset(['Improperly,HUMAN,Not']): 0.01, frozenset(['Straight']): 0.63, frozenset(["Entered,2011,IN,1,,VOLV,ENVMT,Animal's"]): 0.01, frozenset(['2013,11556751,PICKUP']): 0.01, frozenset(['Entered,2004,SC,1,,FORD,HUMAN,Following']): 0.01, frozenset(['Entered,2012,NY,1,,CHEV,HUMAN,Not']): 0.01, frozenset(['Entered,,,1,,,HUMAN,Unknown,HUMAN,Unknown,Not']): 0.01, frozenset(['Applicable,1N4AL2AP3BN']): 0.01, frozenset(['Obstructed/Limited,"Other']): 0.01, frozenset(['Too']): 0.16, frozenset(['Entered,2012,NJ,4,,AUDI,VEHICLE,Other*,HUMAN,Not']): 0.01, frozenset(['2013,11542677,PICKUP']): 0.01, frozenset(['Applicable,1FDAF56Y38E']): 0.01, frozenset(['Closely,HUMAN,Following']): 0.01, frozenset(['Traffic,Not']): 0.05, frozenset(['TRUCK,POLITICAL']): 0.01, frozenset(['Speed,HUMAN,Not']): 0.01, frozenset(['With']): 0.05, frozenset(['Entered,West,Not']): 0.18, frozenset(['Applicable,3C4FY48B05T']): 0.01, frozenset(['2013,11549669,4']): 0.01, frozenset(['Obstructed/Limited,HUMAN,Failure']): 0.01, frozenset(['Entered,Backing,Not']): 0.02, frozenset(['2012,10742629,DUMP,Not']): 0.01, frozenset(['Lanes,Not']): 0.01, frozenset(['Disregarded,HUMAN,Not']): 0.02, frozenset(['2013,11169713,4']): 0.01, frozenset(['Entered,East,None,2001,NY,1,0,DODGE,HUMAN,Not']): 0.01, frozenset(['Applicable,1FUJBBCK39L']): 0.01, frozenset(['Entered,2003,GA,1,,FORD,VEHICLE,Other*,HUMAN,Not']): 0.01, frozenset(['2013,10999745,4']): 0.01, frozenset(['Axles']): 0.01, frozenset(['2013,11299375,4']): 0.01, frozenset(['Applicable,1FTWX31Y28E']): 0.01, frozenset(['2013,11256149,2']): 0.01, frozenset(['Entered,South,None,2006,NY,1,0,ME/BE,HUMAN,Following']): 0.01, frozenset(['With",4KAMGABMX3A']): 0.01, frozenset(['OR']): 0.01, ...

# %%
ruleList = ap.generateRules(L, support)
# Out:
# frozenset(['Entered,Going']) --> frozenset(['Ahead,Not']) conf: 1.0
# frozenset(['Ahead,Not']) --> frozenset(['Entered,Going']) conf: 0.888888888889
# frozenset(['Straight']) --> frozenset(['Ahead,Not']) conf: 1.0
# frozenset(['Ahead,Not']) --> frozenset(['Straight']) conf: 1.0
# frozenset(['Entered,Going']) --> frozenset(['Straight']) conf: 1.0
# frozenset(['Straight']) --> frozenset(['Entered,Going']) conf: 0.888888888889
# freqSet: frozenset(['Ahead,Not', 'Straight', 'Entered,Going'])
# frozenset(['Straight', 'Entered,Going']) --> frozenset(['Ahead,Not']) conf: 1.0
# frozenset(['Ahead,Not', 'Entered,Going']) --> frozenset(['Straight']) conf: 1.0
# frozenset(['Ahead,Not', 'Straight']) --> frozenset(['Entered,Going']) conf: 0.888888888889
# m: 1 Hmp1 now: [frozenset(['Ahead,Not']), frozenset(['Straight']), frozenset(['Entered,Going'])]
# Hmp1: [frozenset(['Ahead,Not', 'Straight']), frozenset(['Ahead,Not', 'Entered,Going']), frozenset(['Straight', 'Entered,Going'])]
# frozenset(['Entered,Going']) --> frozenset(['Ahead,Not', 'Straight']) conf: 1.0
# frozenset(['Straight']) --> frozenset(['Ahead,Not', 'Entered,Going']) conf: 0.888888888889
# frozenset(['Ahead,Not']) --> frozenset(['Straight', 'Entered,Going']) conf: 0.888888888889
# Hmp1 after calculate: [frozenset(['Ahead,Not', 'Straight']), frozenset(['Ahead,Not', 'Entered,Going']), frozenset(['Straight', 'Entered,Going'])]
# freqSet: frozenset(['Ahead,Not', 'Straight', 'Entered,Going'])
# frozenset(['Entered,Going']) --> frozenset(['Ahead,Not', 'Straight']) conf: 1.0
# frozenset(['Straight']) --> frozenset(['Ahead,Not', 'Entered,Going']) conf: 0.888888888889
# frozenset(['Ahead,Not']) --> frozenset(['Straight', 'Entered,Going']) conf: 0.888888888889
# m: 2 Hmp1 now: [frozenset(['Ahead,Not', 'Straight']), frozenset(['Ahead,Not', 'Entered,Going']), frozenset(['Straight', 'Entered,Going'])]

# %%
ruleList
# Out:
# [(frozenset({'Entered,Going'}), frozenset({'Ahead,Not'}), 1.0),
#  (frozenset({'Ahead,Not'}), frozenset({'Entered,Going'}), 0.888888888888889),
#  (frozenset({'Straight'}), frozenset({'Ahead,Not'}), 1.0),
#  (frozenset({'Ahead,Not'}), frozenset({'Straight'}), 1.0),
#  (frozenset({'Entered,Going'}), frozenset({'Straight'}), 1.0),
#  (frozenset({'Straight'}), frozenset({'Entered,Going'}), 0.888888888888889),
#  (frozenset({'Entered,Going', 'Straight'}), frozenset({'Ahead,Not'}), 1.0),
#  (frozenset({'Ahead,Not', 'Entered,Going'}), frozenset({'Straight'}), 1.0),
#  (frozenset({'Ahead,Not', 'Straight'}),
#   frozenset({'Entered,Going'}),
#   0.888888888888889),
#  (frozenset({'Entered,Going'}), frozenset({'Ahead,Not', 'Straight'}), 1.0),
#  (frozenset({'Straight'}),
#   frozenset({'Ahead,Not', 'Entered,Going'}),
#   0.888888888888889),
#  (frozenset({'Ahead,Not'}),
#   frozenset({'Entered,Going', 'Straight'}),
#   0.888888888888889),
#  (frozenset({'Entered,Going'}), frozenset({'Ahead,Not', 'Straight'}), 1.0),
#  (frozenset({'Straight'}),
#   frozenset({'Ahead,Not', 'Entered,Going'}),
#   0.888888888888889),
#  (frozenset({'Ahead,Not'}),
#   frozenset({'Entered,Going', 'Straight'}),
#   0.888888888888889)]

# %% [markdown]
# ## References

# %% [markdown]
# * https://github.com/asaini/Apriori/blob/master/apriori.py
#
# * http://adataanalyst.com/machine-learning/apriori-algorithm-python-3-0/
#
# * http://facweb.cs.depaul.edu/mobasher/classes/CSC478/Notes/IPython%20Notebook%20-%20Associations.html
